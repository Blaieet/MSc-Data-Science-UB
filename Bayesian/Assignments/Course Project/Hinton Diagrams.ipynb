# %% [markdown]
# # Hinton Diagrams implementation
#
# Extracted from [Matplotlib](https://matplotlib.org/stable/gallery/specialty_plots/hinton_demo.html)

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt


def hinton(matrix, title, max_weight=None, ax=None):
    """Draw Hinton diagram for visualizing a weight matrix."""
    ax = ax if ax is not None else plt.gca()

    if not max_weight:
        max_weight = 2 ** np.ceil(np.log2(np.abs(matrix).max()))

    ax.patch.set_facecolor('gray')
    ax.set_aspect('equal', 'box')
    ax.xaxis.set_major_locator(plt.NullLocator())
    ax.yaxis.set_major_locator(plt.NullLocator())
    ax.set_title(title)

    for (x, y), w in np.ndenumerate(matrix):
        color = 'white' if w > 0 else 'black'
        size = np.sqrt(abs(w) / max_weight)
        rect = plt.Rectangle([x - size / 2, y - size / 2], size, size,
                             facecolor=color, edgecolor=color)
        ax.add_patch(rect)

    ax.autoscale_view()
    ax.invert_yaxis()

# %% [markdown]
# # Data Loading
#
# pcaMethods

# %%
pcaM_ppca_loadings_3 = pd.read_csv("Data/Loadings/loadings_pcaM_probabilistic.csv")
pcaM_bpca_loadings_3 = pd.read_csv("Data/Loadings/loadings_pcaM_bayesian.csv")
pcaM_ppca_loadings_5 = pd.read_csv("Data/Loadings/loadings_pcaM_probabilistic5.csv")
pcaM_bpca_loadings_5 = pd.read_csv("Data/Loadings/loadings_pcaM_bayesian5.csv")

# %% [markdown]
# rdimtools

# %%
rdim_ppca_loadings_3 = pd.read_csv("Data/Loadings/loadings_rdim_probabilistic.csv")
rdim_bpca_loadings_3 = pd.read_csv("Data/Loadings/loadings_rdim_bayesian.csv")
rdim_ppca_loadings_5 = pd.read_csv("Data/Loadings/loadings_rdim_probabilistic5.csv")
rdim_bpca_loadings_5 = pd.read_csv("Data/Loadings/loadings_rdim_bayesian5.csv")

# %% [markdown]
# Conventional PCA

# %%
#Rdimtools
rdim_conventional = pd.read_csv("Data/Loadings/loadings_rdim_conventional.csv")
rdim_conventional_5 = pd.read_csv("Data/Loadings/loadings_rdim_conventional5.csv")
#pcaMethods
pcaM_conventional = pd.read_csv("Data/Loadings/loadings_pcaM_conventional.csv")
pcaM_conventional_5 = pd.read_csv("Data/Loadings/loadings_pcaM_conventional5.csv")

# %% [markdown]
# # Comparison

# %%
hinton(pcaM_ppca_loadings_3.values,title="Probabilistic PCA Dimension 3, using pcaMethods")
plt.show()
hinton(rdim_ppca_loadings_3.values,title="Probabilistic PCA Dimension 3, using rdimtools")
plt.show()

# %%
hinton(pcaM_ppca_loadings_5.values,title="Probabilistic PCA Dimension 5, using pcaMethods")
plt.show()
hinton(rdim_ppca_loadings_5.values,title="Probabilistic PCA Dimension 5, using rdimtools")
plt.show()

# %%
hinton(pcaM_bpca_loadings_3.values,title="Bayesian PCA Dimension 3, using pcaMethods")
plt.show()
hinton(rdim_bpca_loadings_3.values,title="Bayesian PCA Dimension 3, using rdimtools")
plt.show()

# %%
hinton(pcaM_bpca_loadings_5.values,title="Bayesian PCA Dimension 5, using pcaMethods")
plt.show()
hinton(rdim_ppca_loadings_5.values,title="Probabilistic PCA Dimension 5, using rdimtools")
plt.show()

# %%
hinton(pcaM_conventional_5.values,title="PCA Dimension 5, using pcaMethods")
plt.show()
hinton(pcaM_bpca_loadings_5.values,title="Bayesian PCA Dimension 5, using pcaMethods")
plt.show()

# %%
hinton(pcaM_conventional_5.values,title="PCA Dimension 5, using pcaMethods")
plt.show()
hinton(pcaM_ppca_loadings_5.values,title="Probabilistic PCA Dimension 5, using pcaMethods")
plt.show()

# %%
hinton(pcaM_conventional.values,title="PCA Dimension 3, using pcaMethods")
plt.show()
hinton(pcaM_bpca_loadings_3.values,title="Bayesian PCA Dimension 3, using pcaMethods")
plt.show()

# %%
hinton(rdim_conventional_5.values,title="PCA Dimension 5, using rdimtools")
plt.show()
hinton(rdim_bpca_loadings_5.values,title="Bayesian PCA Dimension 5, using rdimtools")
plt.show()
