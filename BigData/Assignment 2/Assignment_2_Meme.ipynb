# %% [markdown]
# # Assignment 2
#
# #### First Name:  Montserrat
# #### Last Name: Comas

# %% [markdown]
# *Note that the file path is modified since it is stored in DBFS (spark notebook docker image not working for my MacBook Chip M1)*

# %% [markdown]
# ## 1. Load Data from JSON

# %%
from pyspark.sql import SparkSession 
spark = SparkSession.builder.appName("Twitter Analysis")\
.getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_twitter = spark.read.json("/FileStore/tables/corona_tweet_new.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_twitter.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- created_at: string (nullable = true)
# -- favorite_count: long (nullable = true)
# -- hashtags: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- id: string (nullable = true)
# -- in_reply_to_status_id: string (nullable = true)
# -- in_reply_to_user_id_str: string (nullable = true)
# -- location: string (nullable = true)
# -- reply_count: long (nullable = true)
# -- retweet_count: long (nullable = true)
# -- source: string (nullable = true)
# -- user: struct (nullable = true)
#     |-- contributors_enabled: boolean (nullable = true)
#     |-- created_at: string (nullable = true)
#     |-- default_profile: boolean (nullable = true)
#     |-- default_profile_image: boolean (nullable = true)
#     |-- description: string (nullable = true)
#     |-- favourites_count: long (nullable = true)
#     |-- follow_request_sent: string (nullable = true)
#     |-- followers_count: long (nullable = true)
#     |-- following: string (nullable = true)
#     |-- friends_count: long (nullable = true)
#     |-- geo_enabled: boolean (nullable = true)
#     |-- id: long (nullable = true)
#     |-- id_str: string (nullable = true)
#     |-- is_translator: boolean (nullable = true)
#     |-- lang: string (nullable = true)
#     |-- listed_count: long (nullable = true)
#     |-- location: string (nullable = true)
#     |-- name: string (nullable = true)
#     |-- notifications: string (nullable = true)
#     |-- profile_background_color: string (nullable = true)
#     |-- profile_background_image_url: string (nullable = true)
#     |-- profile_background_image_url_https: string (nullable = true)
#     |-- profile_background_tile: boolean (nullable = true)
#     |-- profile_banner_url: string (nullable = true)
#     |-- profile_image_url: string (nullable = true)
#     |-- profile_image_url_https: string (nullable = true)
#     |-- profile_link_color: string (nullable = true)
#     |-- profile_sidebar_border_color: string (nullable = true)
#     |-- profile_sidebar_fill_color: string (nullable = true)
#     |-- profile_text_color: string (nullable = true)
#     |-- profile_use_background_image: boolean (nullable = true)
#     |-- protected: boolean (nullable = true)
#     |-- screen_name: string (nullable = true)
#     |-- statuses_count: long (nullable = true)
#     |-- time_zone: string (nullable = true)
#     |-- translator_type: string (nullable = true)
#     |-- url: string (nullable = true)
#     |-- utc_offset: string (nullable = true)
#     |-- verified: boolean (nullable = true)
#
# </div>

# %%
### From the user nestec col select the following cols only id_str,followers_count,friends_count and created at 
# (2 points)
from pyspark.sql.functions import col 
df_twitter=df_twitter.select(df_twitter.created_at,
                             df_twitter.favorite_count,
                             df_twitter.hashtags,
                             df_twitter.id,
                             df_twitter.in_reply_to_status_id,
                             df_twitter.in_reply_to_user_id_str,
                             df_twitter.location,
                             df_twitter.reply_count,
                             df_twitter.retweet_count,
                             df_twitter.source,
                             df_twitter.user.id_str.alias('user_id_str'),
                             df_twitter.user.followers_count.alias('user_followers_count'),
                             df_twitter.user.friends_count.alias('user_friends_count'),
                             df_twitter.user.created_at.alias('user_created_at'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_twitter.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- created_at: string (nullable = true)
# -- favorite_count: long (nullable = true)
# -- hashtags: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- id: string (nullable = true)
# -- in_reply_to_status_id: string (nullable = true)
# -- in_reply_to_user_id_str: string (nullable = true)
# -- location: string (nullable = true)
# -- reply_count: long (nullable = true)
# -- retweet_count: long (nullable = true)
# -- source: string (nullable = true)
# -- user_id_str: string (nullable = true)
# -- user_followers_count: long (nullable = true)
# -- user_friends_count: long (nullable = true)
# -- user_created_at: string (nullable = true)
#
# </div>

# %%
# Print the total count of number of records in df_twitter(1 point)
df_twitter.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 15894</div>

# %%
# Extract the source lable from source col by droping the anchor tab and save it as another col named extracted_source
# for example <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a> => Twitter Web App
# you can use "<a [^>]+>([^<]+)" as regualr expresion and the group would be 1 for this regular expression.
#(4 points)
from pyspark.sql.functions import regexp_extract, col

df_twitter=df_twitter.withColumn('extracted_source', regexp_extract(col('source'), "<a [^>]+>([^<]+)", 1))
df_twitter.select(col('extracted_source'),col('source')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
#    extracted_source|              source|
# +-------------------+--------------------+
#     Twitter Web App|&lt;a href=&#34;https://...|
# Twitter for Android|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
#     Twitter Web App|&lt;a href=&#34;https://...|
#  Twitter Web Client|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
#  Twitter for iPhone|&lt;a href=&#34;http://t...|
#  Twitter for iPhone|&lt;a href=&#34;http://t...|
#     Twitter Web App|&lt;a href=&#34;https://...|
# Twitter for Android|&lt;a href=&#34;http://t...|
#     Twitter Web App|&lt;a href=&#34;https://...|
#  Twitter for iPhone|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
#  Twitter for iPhone|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
#  Twitter for iPhone|&lt;a href=&#34;http://t...|
# Twitter for Android|&lt;a href=&#34;http://t...|
# +-------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# Convert the DataFrame into RDD
rdd_twitter=df_twitter.rdd.map(tuple)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a temporay table in memory with name as twitter (1 point)
df_twitter.createOrReplaceTempView("twitter")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2. Analyze Data
#
# #### You will be writing code to find the answer to the questions listed below using Just RDD, Using spark SQL
#
# - Analyze using RDD
# - Analyze using Dataframe without temp table
# - Analyze using spark.sql with temp table

# %%
columns_dic = dict()
for i, name in enumerate(df_twitter.columns):
  columns_dic[name] = i
columns_dic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: {&#39;created_at&#39;: 0,
#  &#39;favorite_count&#39;: 1,
#  &#39;hashtags&#39;: 2,
#  &#39;id&#39;: 3,
#  &#39;in_reply_to_status_id&#39;: 4,
#  &#39;in_reply_to_user_id_str&#39;: 5,
#  &#39;location&#39;: 6,
#  &#39;reply_count&#39;: 7,
#  &#39;retweet_count&#39;: 8,
#  &#39;source&#39;: 9,
#  &#39;user_id_str&#39;: 10,
#  &#39;user_followers_count&#39;: 11,
#  &#39;user_friends_count&#39;: 12,
#  &#39;user_created_at&#39;: 13,
#  &#39;extracted_source&#39;: 14}</div>

# %%
columns_dic['user_id_str']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 10</div>

# %% [markdown]
# #### 2.1 Get total number of unique users (1 point for each type)

# %%
# Using RDD
rdd_user_count = rdd_twitter.map(lambda x: x[columns_dic['user_id_str']]).distinct()
rdd_user_count.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 14094</div>

# %%
# Using DataFramez
df_user_count = df_twitter.select('user_id_str').distinct()
df_user_count.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 14094</div>

# %%
# Using spark.sql and the temporay table.
spark.sql('SELECT COUNT(DISTINCT(user_id_str)) FROM twitter').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------------+
# count(DISTINCT user_id_str)|
# +---------------------------+
#                       14094|
# +---------------------------+
#
# </div>

# %% [markdown]
# #### 2.2 Get count of user who have more than 1 tweet in the data (2 points)

# %%
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Using RDD
rdd_user_tweet_count = rdd_twitter.map(lambda x: x[columns_dic['user_id_str']]).countByValue()
rdd_user_count.filter(lambda x: rdd_user_tweet_count[x]>1).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 1016</div>

# %%
# Using DataFrame
df_user_tweet_count = df_twitter.groupby('user_id_str').agg(F.count('id').alias('num_tweets'))
df_user_tweet_count.filter(F.col('num_tweets')>1).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 1016</div>

# %%
# Using spark.sql and the temporay table.
spark.sql("SELECT count(num_tweets) \
          FROM (\
            SELECT count(id) as num_tweets \
            FROM twitter \
            group by user_id_str\
          ) where num_tweets>1 ").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
# count(num_tweets)|
# +-----------------+
#              1016|
# +-----------------+
#
# </div>

# %% [markdown]
# #### 2.3 Get total number unique extracted_source (1 point each)

# %%
# Using RDD
rdd_source_distinct=rdd_twitter.map(lambda x: x[columns_dic['extracted_source']]).distinct()
rdd_source_distinct.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 133</div>

# %%
# Using DataFrame
df_source_distinct = df_twitter.select('extracted_source').distinct()
df_source_distinct.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 133</div>

# %%
# Using spark.sql and the temporay table.
spark.sql("SELECT \
           COUNT(DISTINCT(extracted_source)) \
           FROM twitter").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------------------+
# count(DISTINCT extracted_source)|
# +--------------------------------+
#                              133|
# +--------------------------------+
#
# </div>

# %% [markdown]
# #### 2.4 Get top 5 most used extracted_source

# %%
# Using RDD (5 points)
rdd_source_count=rdd_twitter.map(lambda x: x[columns_dic['extracted_source']]).countByValue()
top_5_source=rdd_source_distinct.takeOrdered(5, key=lambda x: -rdd_source_count[x])
top_5_source, [rdd_source_count[top_source] for top_source in top_5_source]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: ([&#39;Twitter for Android&#39;,
#   &#39;Twitter for iPhone&#39;,
#   &#39;Twitter Web App&#39;,
#   &#39;Twitter for iPad&#39;,
#   &#39;Twitter Web Client&#39;],
#  [6262, 5698, 2878, 428, 136])</div>

# %%
# Using DataFrame (2 points)
df_source_count=df_twitter.groupBy("extracted_source").agg(F.count('extracted_source').alias('count_source'))
display(df_source_count.sort(F.col('count_source').desc()).head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_source</th><th>count_source</th></tr></thead><tbody><tr><td>Twitter for Android</td><td>6262</td></tr><tr><td>Twitter for iPhone</td><td>5698</td></tr><tr><td>Twitter Web App</td><td>2878</td></tr><tr><td>Twitter for iPad</td><td>428</td></tr><tr><td>Twitter Web Client</td><td>136</td></tr></tbody></table></div>

# %%
# Using spark.sql and the temporay table. (2 points)
spark.sql("SELECT \
          extracted_source, \
          COUNT(extracted_source) as count_source \
          FROM twitter \
          GROUP BY extracted_source \
          ORDER BY count_source DESC").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------+
#    extracted_source|count_source|
# +-------------------+------------+
# Twitter for Android|        6262|
#  Twitter for iPhone|        5698|
#     Twitter Web App|        2878|
#    Twitter for iPad|         428|
#  Twitter Web Client|         136|
# +-------------------+------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# #### 2.5 Get count of distinct hastags used ( 5 point each)

# %%
# Using RDD
rdd_hashtags = rdd_twitter.flatMap(lambda x: x[columns_dic['hashtags']])
rdd_hashtags.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: 1215</div>

# %%
# Using DataFrame
df_twitter.select(F.explode(F.col('hashtags'))).distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 1215</div>

# %%
# Using spark.sql and the temporay table.
spark.sql("SELECT \
          count(aux_col) \
          FROM ( \
            SELECT \
            DISTINCT(EXPLODE(hashtags)) as aux_col \
            FROM twitter \
          ) aux").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+
# count(aux_col)|
# +--------------+
#           1215|
# +--------------+
#
# </div>

# %% [markdown]
# #### 2.6 Get top 5 hashtags

# %%
# Using RDD (4 points)
hashtags_dic = rdd_hashtags.countByValue()
keys_rdd = rdd_hashtags.distinct()
rdd_top_5_hashtags = keys_rdd.map(lambda x: (x, hashtags_dic[x])).takeOrdered(5, lambda w: -w[1])
rdd_top_5_hashtags
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [(&#39;طبق_القدرات_للثانويه_ياريس&#39;, 385),
#  (&#39;Corona&#39;, 319),
#  (&#39;OilPrice&#39;, 251),
#  (&#39;COVID19&#39;, 125),
#  (&#39;corona&#39;, 123)]</div>

# %%
# Using DataFrame (2 points)
hashtags_df = df_twitter.select(F.explode('hashtags').alias('expl_hasthags'))
df_count_hashtags = hashtags_df.groupBy("expl_hasthags").agg(F.count('expl_hasthags').alias('hashtag_count'))

display(df_count_hashtags.sort(F.col('hashtag_count').desc()).head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>expl_hasthags</th><th>hashtag_count</th></tr></thead><tbody><tr><td>طبق_القدرات_للثانويه_ياريس</td><td>385</td></tr><tr><td>Corona</td><td>319</td></tr><tr><td>OilPrice</td><td>251</td></tr><tr><td>COVID19</td><td>125</td></tr><tr><td>corona</td><td>123</td></tr></tbody></table></div>

# %%
columns_dic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: {&#39;created_at&#39;: 0,
#  &#39;favorite_count&#39;: 1,
#  &#39;hashtags&#39;: 2,
#  &#39;id&#39;: 3,
#  &#39;in_reply_to_status_id&#39;: 4,
#  &#39;in_reply_to_user_id_str&#39;: 5,
#  &#39;location&#39;: 6,
#  &#39;reply_count&#39;: 7,
#  &#39;retweet_count&#39;: 8,
#  &#39;source&#39;: 9,
#  &#39;user_id_str&#39;: 10,
#  &#39;user_followers_count&#39;: 11,
#  &#39;user_friends_count&#39;: 12,
#  &#39;user_created_at&#39;: 13,
#  &#39;extracted_source&#39;: 14}</div>

# %%
# Using spark.sql and the temporay table. (2 points)
spark.sql("SELECT \
          expl_hashtags, \
          COUNT(expl_hashtags) as count_hasthag  \
          FROM (\
            SELECT EXPLODE(hashtags) as expl_hashtags \
            FROM twitter \
          ) \
          GROUP BY expl_hashtags \
          ORDER BY count_hasthag DESC").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------+
#        expl_hashtags|count_hasthag|
# +--------------------+-------------+
# طبق_القدرات_للثان...|          385|
#               Corona|          319|
#             OilPrice|          251|
#              COVID19|          125|
#               corona|          123|
# +--------------------+-------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# #### 2.7 Get total number of tweets which are retweeted more than 100 times

# %%
# Using RDD
rdd_retweet = rdd_twitter.filter(lambda x: x[columns_dic['retweet_count']]>100)
rdd_retweet.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: 15753</div>

# %%
# Using DataFrame
df_retweet = df_twitter.filter(F.col("retweet_count")>100)
df_retweet.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 15753</div>

# %%
# Using spark.sql and the temporay table.
spark.sql("SELECT \
          count(id) \
          FROM twitter \
          WHERE retweet_count>100 ").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# count(id)|
# +---------+
#     15753|
# +---------+
#
# </div>

# %% [markdown]
# #### 2.8 Get top 3 most retweeted tweets per country (8 points)

# %%
from pyspark.sql.window import Window
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
columns_dic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: {&#39;created_at&#39;: 0,
#  &#39;favorite_count&#39;: 1,
#  &#39;hashtags&#39;: 2,
#  &#39;id&#39;: 3,
#  &#39;in_reply_to_status_id&#39;: 4,
#  &#39;in_reply_to_user_id_str&#39;: 5,
#  &#39;location&#39;: 6,
#  &#39;reply_count&#39;: 7,
#  &#39;retweet_count&#39;: 8,
#  &#39;source&#39;: 9,
#  &#39;user_id_str&#39;: 10,
#  &#39;user_followers_count&#39;: 11,
#  &#39;user_friends_count&#39;: 12,
#  &#39;user_created_at&#39;: 13,
#  &#39;extracted_source&#39;: 14}</div>

# %%
# Using RDD
import numpy as np
rdd_retweet_country = rdd_twitter.map(lambda x: (x[columns_dic['location']],[x[columns_dic['id']],x[columns_dic['retweet_count']]])).groupByKey().mapValues(lambda x: np.sort(list(x),axis=0)[-3:])

rdd_retweet_country.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: [(&#39;India&#39;,
#   array([[&#39;1252336674580791297&#39;, &#39;9973&#39;],
#          [&#39;1252336682713649152&#39;, &#39;9976&#39;],
#          [&#39;1252336686362738689&#39;, &#39;9988&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Pakistan&#39;,
#   array([[&#39;1252336687037837312&#39;, &#39;9973&#39;],
#          [&#39;1252336695778762752&#39;, &#39;9975&#39;],
#          [&#39;1252336698320658436&#39;, &#39;9988&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;USA&#39;,
#   array([[&#39;1252336697825689601&#39;, &#39;9982&#39;],
#          [&#39;1252336698274562053&#39;, &#39;9987&#39;],
#          [&#39;1252336700170424322&#39;, &#39;9994&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Italy&#39;,
#   array([[&#39;1252336679295373315&#39;, &#39;9971&#39;],
#          [&#39;1252336682302488581&#39;, &#39;9984&#39;],
#          [&#39;1252336687113355269&#39;, &#39;9994&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Canada&#39;,
#   array([[&#39;1252336697469272066&#39;, &#39;9987&#39;],
#          [&#39;1252336698245222400&#39;, &#39;9992&#39;],
#          [&#39;1252336701294469120&#39;, &#39;9997&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;China&#39;,
#   array([[&#39;1252336667735863296&#39;, &#39;999&#39;],
#          [&#39;1252336671917510660&#39;, &#39;9993&#39;],
#          [&#39;1252336676778545152&#39;, &#39;9998&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Chile&#39;,
#   array([[&#39;1252336662773932032&#39;, &#39;9978&#39;],
#          [&#39;1252336667010236416&#39;, &#39;9984&#39;],
#          [&#39;1252336672265564160&#39;, &#39;9988&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;UK&#39;,
#   array([[&#39;1252336669778272256&#39;, &#39;9985&#39;],
#          [&#39;1252336677395197953&#39;, &#39;9989&#39;],
#          [&#39;1252336683753730057&#39;, &#39;9991&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Mexico&#39;,
#   array([[&#39;1252336683644747776&#39;, &#39;9971&#39;],
#          [&#39;1252336690284204032&#39;, &#39;9994&#39;],
#          [&#39;1252336699230892040&#39;, &#39;9998&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Spain&#39;,
#   array([[&#39;1252336686773800963&#39;, &#39;9969&#39;],
#          [&#39;1252336699121664000&#39;, &#39;9981&#39;],
#          [&#39;1252336700627521537&#39;, &#39;9992&#39;]], dtype=&#39;&lt;U19&#39;)),
#  (&#39;Germany&#39;,
#   array([[&#39;1252336672403947521&#39;, &#39;9990&#39;],
#          [&#39;1252336672512962561&#39;, &#39;9997&#39;],
#          [&#39;1252336686769434631&#39;, &#39;9999&#39;]], dtype=&#39;&lt;U19&#39;))]</div>

# %%
# Using DataFrame
df_retweet_country = df_twitter\
  .select('id', 'location', 'retweet_count')\
  .withColumn('rt_loc_rank', F.dense_rank().over(Window.partitionBy('location').orderBy(F.desc('retweet_count'))))

display(df_retweet_country.filter(F.col('rt_loc_rank')<=3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>retweet_count</th><th>rt_loc_rank</th></tr></thead><tbody><tr><td>1252335430323888128</td><td>Canada</td><td>9997</td><td>1</td></tr><tr><td>1252254877939531776</td><td>Canada</td><td>9992</td><td>2</td></tr><tr><td>1252252082825986051</td><td>Canada</td><td>9987</td><td>3</td></tr><tr><td>1252253612140490759</td><td>Chile</td><td>9988</td><td>1</td></tr><tr><td>1252334891951427585</td><td>Chile</td><td>9984</td><td>2</td></tr><tr><td>1252253710182481920</td><td>Chile</td><td>9978</td><td>3</td></tr><tr><td>1252335780707684352</td><td>China</td><td>9998</td><td>1</td></tr><tr><td>1252253596516843520</td><td>China</td><td>9993</td><td>2</td></tr><tr><td>1252255562525560832</td><td>China</td><td>9984</td><td>3</td></tr><tr><td>1252334028092399622</td><td>Germany</td><td>9999</td><td>1</td></tr><tr><td>1252330902325248000</td><td>Germany</td><td>9997</td><td>2</td></tr><tr><td>1252252295510855682</td><td>Germany</td><td>9990</td><td>3</td></tr><tr><td>1252332114948874240</td><td>India</td><td>9988</td><td>1</td></tr><tr><td>1252252336921206787</td><td>India</td><td>9976</td><td>2</td></tr><tr><td>1252254519116746754</td><td>India</td><td>9973</td><td>3</td></tr><tr><td>1252252106750377996</td><td>Italy</td><td>9994</td><td>1</td></tr><tr><td>1252251206027816960</td><td>Italy</td><td>9984</td><td>2</td></tr><tr><td>1252330500670337024</td><td>Italy</td><td>9971</td><td>3</td></tr><tr><td>1252253843145912320</td><td>Mexico</td><td>9998</td><td>1</td></tr><tr><td>1252255209776189442</td><td>Mexico</td><td>9994</td><td>2</td></tr><tr><td>1252252016006422533</td><td>Mexico</td><td>9971</td><td>3</td></tr><tr><td>1252334264248606720</td><td>Pakistan</td><td>9988</td><td>1</td></tr><tr><td>1252251912084357121</td><td>Pakistan</td><td>9975</td><td>2</td></tr><tr><td>1252252126694309888</td><td>Pakistan</td><td>9973</td><td>3</td></tr><tr><td>1252335445876367361</td><td>Spain</td><td>9992</td><td>1</td></tr><tr><td>1252334839094599681</td><td>Spain</td><td>9981</td><td>2</td></tr><tr><td>1252254696112300032</td><td>Spain</td><td>9969</td><td>3</td></tr><tr><td>1252333018578145280</td><td>UK</td><td>9991</td><td>1</td></tr><tr><td>1252252091822870529</td><td>UK</td><td>9989</td><td>2</td></tr><tr><td>1252254043973603329</td><td>UK</td><td>9985</td><td>3</td></tr><tr><td>1252331777806524416</td><td>USA</td><td>9994</td><td>1</td></tr><tr><td>1252254239805579264</td><td>USA</td><td>9987</td><td>2</td></tr><tr><td>1252335464750735362</td><td>USA</td><td>9982</td><td>3</td></tr></tbody></table></div>

# %%
# Using spark.sql and the temporay table.
spark.sql("SELECT * \
          FROM (\
            SELECT \
            location,\
            id,\
            retweet_count,\
            ROW_NUMBER() \
            OVER (PARTITION BY location ORDER BY retweet_count DESC) as rt_loc_rank \
            FROM twitter\
          ) aux_table \
          WHERE rt_loc_rank <= 3").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-------------------+-------------+-----------+
# location|                 id|retweet_count|rt_loc_rank|
# +--------+-------------------+-------------+-----------+
#   Canada|1252335430323888128|         9997|          1|
#   Canada|1252254877939531776|         9992|          2|
#   Canada|1252252082825986051|         9987|          3|
#    Chile|1252253612140490759|         9988|          1|
#    Chile|1252334891951427585|         9984|          2|
#    Chile|1252253710182481920|         9978|          3|
#    China|1252335780707684352|         9998|          1|
#    China|1252253596516843520|         9993|          2|
#    China|1252255562525560832|         9984|          3|
#  Germany|1252334028092399622|         9999|          1|
#  Germany|1252330902325248000|         9997|          2|
#  Germany|1252252295510855682|         9990|          3|
#    India|1252332114948874240|         9988|          1|
#    India|1252252336921206787|         9976|          2|
#    India|1252254519116746754|         9973|          3|
#    Italy|1252252106750377996|         9994|          1|
#    Italy|1252251206027816960|         9984|          2|
#    Italy|1252330500670337024|         9971|          3|
#   Mexico|1252253843145912320|         9998|          1|
#   Mexico|1252255209776189442|         9994|          2|
# +--------+-------------------+-------------+-----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### 2.9 Total number of tweets per country

# %%
# Using RDD (3 points)
rdd_loc = rdd_twitter.map(lambda x: x[columns_dic['location']])
rdd_loc.countByValue()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: defaultdict(int,
#             {&#39;India&#39;: 1480,
#              &#39;UK&#39;: 1376,
#              &#39;Spain&#39;: 1464,
#              &#39;USA&#39;: 1539,
#              &#39;Canada&#39;: 1441,
#              &#39;China&#39;: 1457,
#              &#39;Pakistan&#39;: 1470,
#              &#39;Germany&#39;: 1426,
#              &#39;Mexico&#39;: 1409,
#              &#39;Chile&#39;: 1410,
#              &#39;Italy&#39;: 1422})</div>

# %%
# Using DataFrame (2 points)
df_loc = df_twitter.groupBy('location').agg(F.count('location').alias('tweets_per_country'))
df_loc.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------------------+
# location|tweets_per_country|
# +--------+------------------+
#  Germany|              1426|
#    India|              1480|
#    China|              1457|
#    Chile|              1410|
#    Italy|              1422|
#    Spain|              1464|
#      USA|              1539|
#   Mexico|              1409|
#       UK|              1376|
#   Canada|              1441|
# Pakistan|              1470|
# +--------+------------------+
#
# </div>

# %%
# Using spark.sql and the temporay table. (1 point)
spark.sql("SELECT \
          location,\
          COUNT(location) as tweets_per_country \
          FROM twitter \
          GROUP BY location").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------------------+
# location|tweets_per_country|
# +--------+------------------+
#  Germany|              1426|
#    India|              1480|
#    China|              1457|
#    Chile|              1410|
#    Italy|              1422|
#    Spain|              1464|
#      USA|              1539|
#   Mexico|              1409|
#       UK|              1376|
#   Canada|              1441|
# Pakistan|              1470|
# +--------+------------------+
#
# </div>

# %% [markdown]
# ## 3. Save Data

# %% [markdown]
# #### 3.1 save the data such that you have seperate folder per country (2 points)

# %%
# Using DataFrame
df_twitter.write.partitionBy("location").format("json").save("corona_tweet_by_loc.json")

# %% [markdown]
# #### 3.2 Save the data as parquet files (1 points)

# %%
# Using DataFrame
# partitions by location: df_twitter.write.partitionBy("location").format("parquet").save("corona_tweet_by_loc.parquet")

# default partitions:
df_twitter.write.format("parquet").save("corona_tweet_out.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
