# %% [markdown]
# ## 1. Using the API
#
# Recall the **big picture**. If we are targeting for specific data we could check if the web site has a programatic interface for querying. If it has we can use it.

# %% [markdown]
# <img style="border-radius:20px;" src="./files/big_picture.jpg">

# %% [markdown]
# ## Scrapping twitter data with the API

# %% [markdown]
# A standard way for programatically communicating with a web service is using the API (Application Programing Interface) whenever it is provided. Twitter provides several APIs. The two most important ones are the RESTful API for static queries (e.g. user's friends and followers, check timelines, etc) and the Streaming API for retrieving live data. The REST API identifies Twitter applications and users using OAuth; responses are available in JSON. The Streaming API should not need authentication.
#
# Ex.
#
# https://api.twitter.com/oauth/authenticate?oauth_token=XXXXXXXXXXXXXX
#
# https://api.twitter.com/1.1/followers/ids.json?cursor=-1&screen_name=my_user_name&count=5000
#
# Building these queries is not always easy, thus we may use a wrapper around the API. This is what **tweepy** does.

# %% [markdown]
# Using the API with authentification (needed for the RESTful API)
#
# From wikipedia:
#
# >"Web service APIs that adhere to the architectural constraints are called RESTful. HTTP based RESTful APIs are defined with these aspects:
#
# > <ul><li>base URI, such as http://example.com/resources/
# <li>an Internet media type for the data. This is often JSON but can be any other valid Internet media type (e.g. XML, Atom, microformats, images, etc.)</li>
# <li>standard HTTP methods (e.g., GET, PUT, POST, or DELETE)</li>
# <li>hypertext links to reference state</li>
# <li>hypertext links to reference related resources"</li>
# </ul>
#
# If we want to use the RESTful API in Twitter we have to follow these steps:
# <ul>
# <li>From your twitter account we want to generate a token: https://developer.twitter.com/en/apps</li>
# <li>Create a new App. This will create the API keys (consumer keys)</li>
# <li>Go to API Keys and generate a token. (access keys)</li>
# <li> Write them down in files **consumer_key**, **consumer_secret**, **access_key**, **access_secret**
# <li> Check Tweepy API reference: http://docs.tweepy.org/en/v3.5.0/api.html
# </ul>

# %%
import json
import pymongo
import tweepy

with open('consumer_key', 'r') as f:
    consumer_key =  f.read()
f.closed

with open('consumer_secret', 'r') as f:
    consumer_secret = f.read()
f.closed

with open('access_key', 'r') as f:
    access_key = f.read()
f.closed

with open('access_secret', 'r') as f:
     access_secret = f.read()
f.closed


#Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)


#Do something
USER_NAME = "eloipuertas"
user = api.get_user(id=USER_NAME)
print (user)
# Out:
# User(_api=<tweepy.api.API object at 0x10d50c2b0>, _json={'id': 484683149, 'id_str': '484683149', 'name': 'Eloi Puertas Prats', 'screen_name': 'eloipuertas', 'location': 'Univeristat de Barcelona', 'profile_location': None, 'description': 'Distributed Software and Agile Data Science teacher. Director of Studies Eng. Informàtica. UB. DatabeersBCN co-founder.', 'url': 'https://t.co/hbfA0tesFa', 'entities': {'url': {'urls': [{'url': 'https://t.co/hbfA0tesFa', 'expanded_url': 'http://ub-gei-sd.github.io/', 'display_url': 'ub-gei-sd.github.io', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 692, 'friends_count': 557, 'listed_count': 194, 'created_at': 'Mon Feb 06 11:23:33 +0000 2012', 'favourites_count': 6576, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 6886, 'lang': None, 'status': {'created_at': 'Fri Jul 12 13:18:12 +0000 2019', 'id': 1149669288665419776, 'id_str': '1149669288665419776', 'text': 'RT @submariblau: Una edició més (la meva 16a!) participant al #CampusItaca @UABBarcelona amb taller #Robots ; content d contribuir a motiva…', 'truncated': False, 'entities': {'hashtags': [{'text': 'CampusItaca', 'indices': [62, 74]}, {'text': 'Robots', 'indices': [100, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'submariblau', 'name': 'Jordi Campos Miralles 🎗️', 'id': 817475652, 'id_str': '817475652', 'indices': [3, 15]}, {'screen_name': 'UABBarcelona', 'name': 'Universitat Autònoma de Barcelona', 'id': 304338078, 'id_str': '304338078', 'indices': [75, 88]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Jul 12 10:10:19 +0000 2019', 'id': 1149622006188408832, 'id_str': '1149622006188408832', 'text': 'Una edició més (la meva 16a!) participant al #CampusItaca @UABBarcelona amb taller #Robots ; content d contribuir a… https://t.co/i2e9Xppxzp', 'truncated': True, 'entities': {'hashtags': [{'text': 'CampusItaca', 'indices': [45, 57]}, {'text': 'Robots', 'indices': [83, 90]}], 'symbols': [], 'user_mentions': [{'screen_name': 'UABBarcelona', 'name': 'Universitat Autònoma de Barcelona', 'id': 304338078, 'id_str': '304338078', 'indices': [58, 71]}], 'urls': [{'url': 'https://t.co/i2e9Xppxzp', 'expanded_url': 'https://twitter.com/i/web/status/1149622006188408832', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 11, 'favorited': True, 'retweeted': True, 'possibly_sensitive': False, 'lang': 'ca'}, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 0, 'favorited': True, 'retweeted': True, 'lang': 'ca'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C6E2EE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1808176110/eloi_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1808176110/eloi_normal.jpg', 'profile_link_color': '1F98C7', 'profile_sidebar_border_color': 'C6E2EE', 'profile_sidebar_fill_color': 'DAECF4', 'profile_text_color': '663B12', 'profile_use_background_image': True, 'has_extended_profile':  ...

# %% [markdown]
# We can access some basic information about the user

# %%
user.screen_name
# Out:
# 'eloipuertas'

# %%
user.id
# Out:
# 484683149

# %%
user.created_at
# Out:
# datetime.datetime(2012, 2, 6, 11, 23, 33)

# %%
user.friends_count
# Out:
# 557

# %%
user.followers_count
# Out:
# 692

# %%
timeline = api.user_timeline(id=USER_NAME,count=5)
#Retrieve a Status object...

for status in timeline:
    print (status.text+ "\n")
# Out:
# RT @submariblau: Una edició més (la meva 16a!) participant al #CampusItaca @UABBarcelona amb taller #Robots ; content d contribuir a motiva…
#
# RT @pybcn: Send a talk proposal! https://t.co/ge2HfC67ov
#
# RT @VoluntariatUB: La Fundació @FGermina necessita voluntariat per a diverses tasques d'acompanyament a nens i joves @UniBarcelona @Solidar…
#
# RT @BibmatUB: @eloipuertas @oriolpujolvila @Laura_Igual @SeguiSanti @bitenmascarado @lgoster https://t.co/FX7ccrOzj2
#
# RT @dloisga: Una Ministra en Suecia ha dicho "El derecho de los niños a respirar aire limpio tiene prioridad sobre el derecho a conducir to…

# %% [markdown]
# >JSON (JavaScript Object Notation), is an open standard format that uses human-readable text to transmit data objects consisting of attribute–value pairs. It is used primarily to transmit data between a server and web application, as an alternative to XML. JSON is a way to encode complicated information in a platform-independent way.  It could be considered the lingua franca of information exchange on the Internet.

# %%
#We can access the full JSON
user._json
# Out:
# {'id': 484683149,
#  'id_str': '484683149',
#  'name': 'Eloi Puertas Prats',
#  'screen_name': 'eloipuertas',
#  'location': 'Univeristat de Barcelona',
#  'profile_location': None,
#  'description': 'Distributed Software and Agile Data Science teacher. Director of Studies Eng. Informàtica. UB. DatabeersBCN co-founder.',
#  'url': 'https://t.co/hbfA0tesFa',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/hbfA0tesFa',
#      'expanded_url': 'http://ub-gei-sd.github.io/',
#      'display_url': 'ub-gei-sd.github.io',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 692,
#  'friends_count': 557,
#  'listed_count': 194,
#  'created_at': 'Mon Feb 06 11:23:33 +0000 2012',
#  'favourites_count': 6576,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 6886,
#  'lang': None,
#  'status': {'created_at': 'Fri Jul 12 13:18:12 +0000 2019',
#   'id': 1149669288665419776,
#   'id_str': '1149669288665419776',
#   'text': 'RT @submariblau: Una edició més (la meva 16a!) participant al #CampusItaca @UABBarcelona amb taller #Robots ; content d contribuir a motiva…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'CampusItaca', 'indices': [62, 74]},
#     {'text': 'Robots', 'indices': [100, 107]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'submariblau',
#      'name': 'Jordi Campos Miralles 🎗️',
#      'id': 817475652,
#      'id_str': '817475652',
#      'indices': [3, 15]},
#     {'screen_name': 'UABBarcelona',
#      'name': 'Universitat Autònoma de Barcelona',
#      'id': 304338078,
#      'id_str': '304338078',
#      'indices': [75, 88]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Jul 12 10:10:19 +0000 2019',
#    'id': 1149622006188408832,
#    'id_str': '1149622006188408832',
#    'text': 'Una edició més (la meva 16a!) participant al #CampusItaca @UABBarcelona amb taller #Robots ; content d contribuir a… https://t.co/i2e9Xppxzp',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'CampusItaca', 'indices': [45, 57]},
#      {'text': 'Robots', 'indices': [83, 90]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'UABBarcelona',
#       'name': 'Universitat Autònoma de Barcelona',
#       'id': 304338078,
#       'id_str': '304338078',
#       'indices': [58, 71]}],
#     'urls': [{'url': 'https://t.co/i2e9Xppxzp',
#       'expanded_url': 'https://twitter.com/i/web/status/1149622006188408832',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 11,
#    'favorited': True,
#    'retweeted': True,
#    'possibly_sensitive': False,
#    'lang': 'ca'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': True,
#   'retweeted': True,
#   'lang': 'ca'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C6E2EE',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1808176110/eloi_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1808176110/eloi_normal.jpg',
#  'profile_link_color': '1F98C7',
#  'profile_sidebar_border_color': 'C6E2EE',
#  'profile_sidebar_fill_color': 'DAECF4',
#  'profile_text_color': '663B12',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# We can access all the information as it was a dictionary structure.

# %%
juser = user._json
print (juser['created_at'])
# Out:
# Mon Feb 06 11:23:33 +0000 2012

# %% [markdown]
# We can apply our basic scrape knowledge and use urllib to retrieve more interesting infomation, such as the profile image.

# %%
img_url = juser['profile_image_url']
print (img_url)
# Out:
# http://pbs.twimg.com/profile_images/1808176110/eloi_normal.jpg

# %%
import urllib
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt

im = Image.open(urllib.request.urlopen(img_url))
plt.title(juser['screen_name'],size=16)
plt.imshow(im)

# %% [markdown]
# Now we want to retrieve the list of follower ids. There are two ways for doing so. Both uses the `api.followers_ids` function. The function returns a maximum of 100 ids. If we want to get all of them we may use a pagination variable `cursor`. This can be managed directly in the call `api.followers_ids(id, cursor)` or using a `Cursor` object with the `pages` method that handles the cursor implicitly. This second method is illustrated in the following lines:

# %%
import time
#Retrieving all the followers
ids = []
for page in tweepy.Cursor(api.followers_ids, screen_name=USER_NAME).pages():
    print("************** ***************")
    ids.extend(page)
    time.sleep(5)  #This should be 60 to avoid limit rates
ids
# Out:
# ************** ***************
# [937592982,
#  19435796,
#  702214973792063489,
#  1151306876530962432,
#  454143009,
#  2499737527,
#  1146167902640451587,
#  250769102,
#  1426409264,
#  373280522,
#  1854982104,
#  1088451553986396160,
#  1596301758,
#  1097547167663865857,
#  1121041578464821248,
#  925017326176661504,
#  1102567157437747200,
#  2776776884,
#  1040524261402796033,
#  724975951831027713,
#  242945949,
#  8688832,
#  1093596506924507138,
#  9959322,
#  3253200778,
#  1047121682421485568,
#  136267057,
#  18176643,
#  1059437056001236992,
#  1036668815801761795,
#  987734660267565056,
#  796151990,
#  29167187,
#  996832631693209600,
#  223103221,
#  268254897,
#  14235803,
#  846285859,
#  294101019,
#  324312002,
#  242013031,
#  960983420993228801,
#  394179048,
#  954862755072430080,
#  986543125341536257,
#  285779081,
#  1004847776449073152,
#  10284202,
#  124246207,
#  965349922508767233,
#  911633205027065859,
#  2951142813,
#  993985444663758848,
#  156617316,
#  800830869904756745,
#  93046529,
#  402857468,
#  450549446,
#  2487758371,
#  481223244,
#  64643723,
#  58264226,
#  2869033083,
#  254501323,
#  847221577162792960,
#  856429141717118976,
#  139670508,
#  2850821651,
#  245321054,
#  2799501313,
#  7671542,
#  473361521,
#  17705878,
#  1640429246,
#  550857581,
#  916224651654770688,
#  4046794876,
#  892443958898335745,
#  156638737,
#  269724334,
#  301136196,
#  245741737,
#  183686606,
#  210462636,
#  292561685,
#  163605791,
#  959406320062488576,
#  960507168880517125,
#  122011681,
#  2344934544,
#  741353349451239428,
#  54196034,
#  376951298,
#  956083640378777600,
#  739517743951716352,
#  2382186263,
#  3569220435,
#  456785986,
#  69846817,
#  82757802,
#  915855254788419584,
#  166140594,
#  68908905,
#  156741839,
#  306134904,
#  559633081,
#  3792459557,
#  912234254540697601,
#  2951146276,
#  927830731463720960,
#  13068142,
#  83629804,
#  418612132,
#  2269241826,
#  304969342,
#  933824100866371584,
#  232968006,
#  2891874429,
#  2778898043,
#  1394290140,
#  791639546198945792,
#  895590524618493952,
#  910454003686920193,
#  346138644,
#  387052902,
#  805082243974701056,
#  925442137809924096,
#  3363843593,
#  4384800219,
#  1578379231,
#  387596420,
#  248373901,
#  848833207,
#  115435513,
#  921383232628654085,
#  921314458558967808,
#  301095761,
#  3651378796,
#  3575782095,
#  919641829758390273,
#  91878416,
#  269814365,
#  217003548,
#  882982014927941632,
#  370104702,
#  2237217412,
#  3123972317,
#  814552815309910017,
#  887629014852132865,
#  3116152469,
#  101850919,
#  95923034,
#  406640217,
#  939701456,
#  2938507360,
#  335502734,
#  118056488,
#  831170378634518529,
#  1361426652,
#  703903294456991745,
#  432784955,
#  910639245701853186,
#  253969689,
#  221147712,
#  3293070345,
#  204004194,
#  457782697,
#  17018967,
#  2601300402,
#  602691350,
#  272017953,
#  3072113026,
#  507779499,
#  295707423,
#  321869008,
#  1415305356,
#  164580969,
#  21323810,
#  11401032,
#  79481681,
#  2986680826,
#  117812598,
#  8422812,
#  411725263,
#  1448112866,
#  484914221,
#  26205177,
#  3040921024,
#  3081314602,
#  37651758,
#  1389336451,
#  243360585,
#  3073689363,
#  15420213,
#  199308038,
#  517946260,
#  202357066,
#  36965900,
#  2902070014,
#  20428117,
#  2957590109,
#  2215685881,
#  2846454035,
#  407245002,
#  472290100,
#  66995004,
#  473833935,
#  101824202,
#  2389069947,
#  1418887279,
#  2394852604,
#  573815031,
#  545073721,
#  2860929640,
#  255414763,
#  42107224,
#  2799549395,
#  912189476,
#  621713740,
#  84268164,
#  1416427176,
#  2613337543,
#  965799726,
#  1087050162,
#  1356430027,
#  2462975132,
#  2494693307,
#  387056903,
#  494810806,
#  343949885,
#  925733328,
#  431614153,
#  2303127168,
#  884163896,
#  196559225,
#  248902303,
#  884163908,
#  2362871150,
#  2353046334,
#  2351567100,
#  2350995330,
#  2343534206,
#  109020085,
#  2344258957,
#  2272079576,
#  248414814,
#  119046100,
#  1602826087,
#  604552764,
#  17651360,
#  17534675,
#  190801607,
#  235093087,
#  123409488,
#  2226791774,
#  566477082,
#  268978288,
#  1629956154,
#  87549692,
#  251824984,
#  191923703,
#  546251714,
#  306289853,
#  336480218,
#  375680936,
#  819685321,
#  800656297,
#  374143376,
#  1185340694,
#  149683652,
#  14297498,
#  158320381,
#  218499746,
#  927973640,
#  728282412,
#  586892465,
#  501298347,
#  515377526,
#  486780877,
#  493942375,
#  428191807,
#  493773801,
#  260284295,
#  144467049,
#  492958361,
#  165916420,
#  492952564,
#  444134631,
#  112541709,
#  489771973,
#  489953456,
#  488600890,
#  271553064,
#  121527171,
#  240181980,
#  184858631,
#  376120109]

# %% [markdown]
# Notice the `sleep` command. This is needed to respect the hourly limit rates of the Twitter API.

# %%
document={}
document['user'] = user.id
document['followers'] = ids[:]

# Create the connection to MongoDB in local
try:
    conn=pymongo.MongoClient()
    print ("Connection to Mongo Daemon successful!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
db = conn['twitter']
collection = db['twitter_users']
collection.insert_one(document)
# Out:
# Connection to Mongo Daemon successful!!!

# %%
for doc in collection.find():
    print (doc)
# Out:
# {'_id': ObjectId('5d8de4aaf8125b02e0c915d7'), 'user': 484683149, 'followers': [937592982, 19435796, 702214973792063489, 1151306876530962432, 454143009, 2499737527, 1146167902640451587, 250769102, 1426409264, 373280522, 1854982104, 1088451553986396160, 1596301758, 1097547167663865857, 1121041578464821248, 925017326176661504, 1102567157437747200, 2776776884, 1040524261402796033, 724975951831027713, 242945949, 8688832, 1093596506924507138, 9959322, 3253200778, 1047121682421485568, 136267057, 18176643, 1059437056001236992, 1036668815801761795, 987734660267565056, 796151990, 29167187, 996832631693209600, 223103221, 268254897, 14235803, 846285859, 294101019, 324312002, 242013031, 960983420993228801, 394179048, 954862755072430080, 986543125341536257, 285779081, 1004847776449073152, 10284202, 124246207, 965349922
#  1084111308,
#  40834869,
#  3014676567,
#  859567891,
#  483215089,
#  2601300402,
#  602691350,
#  272017953,
#  3072113026,
#  507779499,
#  295707423,
#  321869008,
#  1415305356,
#  164580969,
#  21323810,
#  11401032,
#  79481681,
#  2986680826,
#  117812598,
#  8422812,
#  411725263,
#  1448112866,
#  484914221,
#  26205177,
#  3040921024,
#  3081314602,
#  37651758,
#  1389336451,
#  243360585,
#  3073689363,
#  15420213,
#  199308038,
#  517946260,
#  202357066,
#  36965900,
#  2902070014,
#  20428117,
#  2957590109,
#  2215685881,
#  2846454035,
#  407245002,
#  472290100,
#  66995004,
#  473833935,
#  101824202,
#  2389069947,
#  1418887279,
#  2394852604,
#  573815031,
#  545073721,
#  2860929640,
#  255414763,
#  42107224,
#  2799549395,
#  912189476,
#  621713740,
#  84268164,
#  1416427176,
#  2613337543,
#  965799726,
#  1087050162,
#  1356430027,
#  2462975132,
#  2494693307,
#  387056903,
#  494810806,
#  343949885,
#  925733328,
#  431614153,
#  2303127168,
#  884163896,
#  196559225,
#  248902303,
#  884163908,
#  2362871150,
#  2353046334,
#  2351567100,
#  2350995330,
#  2343534206,
#  109020085,
#  2344258957,
#  2272079576,
#  248414814,
#  119046100,
#  1602826087,
#  604552764,
#  17651360,
#  17534675,
#  190801607,
#  235093087,
#  123409488,
#  2226791774,
#  566477082,
#  268978288,
#  1629956154,
#  87549692,
#  251824984,
#  191923703,
#  546251714,
#  306289853,
#  336480218,
#  375680936,
#  819685321,
#  800656297,
#  374143376,
#  1185340694,
#  149683652,
#  14297498,
#  158320381,
#  218499746,
#  927973640,
#  728282412,
#  586892465,
#  501298347,
#  515377526,
#  486780877,
#  493942375,
#  428191807,
#  493773801,
#  260284295,
#  144467049,
#  492958361,
#  165916420,
#  492952564,
#  444134631,
#  112541709,
#  489771973,
#  489953456,
#  488600890,
#  271553064,
#  121527171,
#  240181980,
#  184858631,
#  376120109]

# %% [markdown]
# <div class = "alert alert-error" style = "border-radius:10px;border-width:3px;border-color:darkred;font-family:Verdana,sans-serif;font-size:16px;"> **EXERCISE:** Given a starting user ID, retrieve the user name, the date of the accoount creation and the last twit text and date corresponding to the whole set of followers. Store it to Database
# </div>

# %% [markdown]
# ### Sreaming API

# %% [markdown]
# The **Streaming API** works by making a request for a specific type of data — filtered by keyword, user, geographic area, or a random sample — and then keeping the connection open as long as there are no errors in the connection. The data you get back will be encoded in JSON.

# %% [markdown]
# One of the main usage cases of tweepy is monitoring for tweets and doing actions when some event happens. Key component of that is the StreamListener object, which monitors tweets in real time and catches them.
#
# If we check the official twitter streaming API we see that we have several modifiers for filtering the stream, i.e. track (filter by keyword), locations (filter by geographic location), etc
#
# StreamListener has several methods, with on_data() and on_status() being the most useful ones. Here is a sample program which implements this behavior:

# %%
from tweepy import Stream,StreamListener

class listener(StreamListener):
    
    def __init__(self):
        super(StreamListener, self).__init__()
        self.num_tweets = 0
    def on_data(self, data):
        #Beauty print data
        if self.num_tweets < 5:
            parsed = json.loads(data)
            print (json.dumps(parsed, indent=4, sort_keys=True))
            self.num_tweets += 1
            return True
        else:
            return False

    def on_error(self, status):
        print (status)

# %% [markdown]
# 1. Get the twitter data filtered by location inside the following bounding box. (http://boundingbox.klokantech.com) (get CSV)

# %% [markdown]
# [2.0878744125,41.465321939,2.0950841904,41.4704350021]

# %%
twitterStream = Stream(auth, listener()) 
twitterStream.filter(locations=[2.067704,41.465322,2.095084,41.478474])
print ("done")
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 27 10:30:47 +0000 2019",
#     "display_text_range": [
#         7,
#         106
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 469313664,
#                 "id_str": "469313664",
#                 "indices": [
#                     0,
#                     6
#                 ],
#                 "name": "Sergi Mu\u00f1iz Carrera",
#                 "screen_name": "s_mc_"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1177531022289899520,
#     "id_str": "1177531022289899520",
#     "in_reply_to_screen_name": "s_mc_",
#     "in_reply_to_status_id": 1177510944957595649,
#     "in_reply_to_status_id_str": "1177510944957595649",
#     "in_reply_to_user_id": 469313664,
#     "in_reply_to_user_id_str": "469313664",
#     "is_quote_status": false,
#     "lang": "es",
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         2.074488,
#                         41.442847
#                     ],
#                     [
#                         2.074488,
#                         41.511163
#                     ],
#                     [
#                         2.15998,
#                         41.511163
#                     ],
#                     [
#                         2.15998,
#                         41.442847
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "country": "Espa\u00f1a",
#         "country_code": "ES",
#         "full_name": "Cerdanyola del Vall\u00e8s, Espa\u00f1a",
#         "id": "ffaf1a469b1c15b1",
#         "name": "Cerdanyola del Vall\u00e8s",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/ffaf1a469b1c15b1.json"
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@s_mc_ Pero tu juegas de vez en cuando nite mam\u00f3n jajaja, es por la nueva skin que regalan con uno de esos",
#     "timestamp_ms": "1569580247839",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Oct 10 14:28:44 +0000 2013",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "\u25ab\ufe0f18\u25ab\ufe0f",
#         "favourites_count": 9081,
#         "follow_request_sent": null,
#         "followers_count": 236,
#         "following": null,
#         "friends_count": 160,
#         "geo_enabled": true,
#         "id": 1951889791,
#         "id_str": "1951889791",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 5,
#         "location": "Pandora",
#         "name": "Niko",
#         "notifications": null,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1951889791/1568651229",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1174512986960125952/XUojRZfu_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1174512986960125952/XUojRZfu_normal.jpg",
#         "profile_link_color": "981CEB",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "Niko_Scooter",
#         "statuses_count": 17590,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://www.instagram.com/nikobarragan",
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": {
#         "coordinates": [
#             2.0852,
#             41.4706
#         ],
#         "type": "Point"
#     },
#     "created_at": "Fri Sep 27 10:30:50 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "instagram.com/p/B26U9USFGuZ/\u2026",
#                 "expanded_url": "https://www.instagram.com/p/B26U9USFGuZ/?igshid=wpcm9tzkfm5",
#                 "indices": [
#                     93,
#                     116
#                 ],
#                 "url": "https://t.co/a25Vzc8kez"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": {
#         "coordinates": [
#             41.4706,
#             2.0852
#         ],
#         "type": "Point"
#     },
#     "id": 1177531032247029761,
#     "id_str": "1177531032247029761",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "ca",
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         1.999829,
#                         41.415036
#                     ],
#                     [
#                         1.999829,
#                         41.519488
#                     ],
#                     [
#                         2.129965,
#                         41.519488
#                     ],
#                     [
#                         2.129965,
#                         41.415036
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "country": "Espa\u00f1a",
#         "country_code": "ES",
#         "full_name": "Sant Cugat del Vall\u00e8s, Espa\u00f1a",
#         "id": "ea962961b94011f1",
#         "name": "Sant Cugat del Vall\u00e8s",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/ea962961b94011f1.json"
#     },
#     "possibly_sensitive": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#     "text": "Protecci\u00f3n refinada creada para personas activas \ud83d\udeb4\ud83c\udfc7\ud83c\udfc2\nLa serie Plyo\ud83d\udcaa en Sant Cugat del Vall\u00e8s https://t.co/a25Vzc8kez",
#     "timestamp_ms": "1569580250213",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Feb 18 20:08:28 +0000 2010",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "#Exertis es uno de los mayores operadores de servicios y distribuci\u00f3n en Europa. #Movilidad #Computing #Gaming #Movilidad #IoT #Audiovideo",
#         "favourites_count": 563,
#         "follow_request_sent": null,
#         "followers_count": 223,
#         "following": null,
#         "friends_count": 239,
#         "geo_enabled": true,
#         "id": 115482929,
#         "id_str": "115482929",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 6,
#         "location": "Barcelona",
#         "name": "Exertis Iberia",
#         "notifications": null,
#         "profile_background_color": "E6D843",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/115482929/1495805692",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1072452861718642690/kvI5ZvN1_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1072452861718642690/kvI5ZvN1_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "FFEA00",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "FFF200",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "exertis_iberia",
#         "statuses_count": 751,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://www.exertis.es",
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 27 10:31:13 +0000 2019",
#     "display_text_range": [
#         33,
#         140
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1177531129517268994",
#                 "indices": [
#                     121,
#                     144
#                 ],
#                 "url": "https://t.co/kawLddT5v8"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 163991506,
#                 "id_str": "163991506",
#                 "indices": [
#                     0,
#                     16
#                 ],
#                 "name": "James Cookson",
#                 "screen_name": "james_m_cookson"
#             },
#             {
#                 "id": 236850119,
#                 "id_str": "236850119",
#                 "indices": [
#                     17,
#                     32
#                 ],
#                 "name": "OTOR",
#                 "screen_name": "OntrackOffroad"
#             }
#         ]
#     },
#     "extended_tweet": {
#         "display_text_range": [
#             33,
#             167
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 163991506,
#                     "id_str": "163991506",
#                     "indices": [
#                         0,
#                         16
#                     ],
#                     "name": "James Cookson",
#                     "screen_name": "james_m_cookson"
#                 },
#                 {
#                     "id": 236850119,
#                     "id_str": "236850119",
#                     "indices": [
#                         17,
#                         32
#                     ],
#                     "name": "OTOR",
#                     "screen_name": "OntrackOffroad"
#                 }
#             ]
#         },
#         "full_text": "@james_m_cookson @OntrackOffroad Thanks James. Yep, right attitude &amp; positivity essential for a project at this stage. Seems Johann couldn\u2019t provide that. A shame."
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1177531129517268994,
#     "id_str": "1177531129517268994",
#     "in_reply_to_screen_name": "james_m_cookson",
#     "in_reply_to_status_id": 1176908746888556544,
#     "in_reply_to_status_id_str": "1176908746888556544",
#     "in_reply_to_user_id": 163991506,
#     "in_reply_to_user_id_str": "163991506",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         2.052477,
#                         41.317048
#                     ],
#                     [
#                         2.052477,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.317048
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "country": "Spain",
#         "country_code": "ES",
#         "full_name": "Barcelona, Spain",
#         "id": "1a27537478dd8e38",
#         "name": "Barcelona",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/1a27537478dd8e38.json"
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "@james_m_cookson @OntrackOffroad Thanks James. Yep, right attitude &amp; positivity essential for a project at this sta\u2026 https://t.co/kawLddT5v8",
#     "timestamp_ms": "1569580273404",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Oct 05 14:38:48 +0000 2012",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "MotoGP reporter for @crash_motogp, @roadracingworld & @OntrackOffroad | Moto2/3 commentator | Host/speak on @PaddockPassPod",
#         "favourites_count": 7126,
#         "follow_request_sent": null,
#         "followers_count": 6967,
#         "following": null,
#         "friends_count": 992,
#         "geo_enabled": true,
#         "id": 863163949,
#         "id_str": "863163949",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 165,
#         "location": "Barcelona, Spain",
#         "name": "Neil Morrison",
#         "notifications": null,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/863163949/1512232965",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/574316047450292224/b7n72Lsb_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/574316047450292224/b7n72Lsb_normal.jpeg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "NeilMorrison87",
#         "statuses_count": 11066,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 27 10:31:15 +0000 2019",
#     "display_text_range": [
#         0,
#         74
#     ],
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     5,
#                     21
#                 ],
#                 "text": "FridayForFuture"
#             },
#             {
#                 "indices": [
#                     38,
#                     53
#                 ],
#                 "text": "transFORMAdors"
#             },
#             {
#                 "indices": [
#                     54,
#                     65
#                 ],
#                 "text": "glocalitat"
#             },
#             {
#                 "indices": [
#                     66,
#                     74
#                 ],
#                 "text": "TUtopia"
#             }
#         ],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/0AVDuZmEfO",
#                 "expanded_url": "https://twitter.com/EscolesFEDAC/status/1177531138736345088/photo/1",
#                 "id": 1177531131077570560,
#                 "id_str": "1177531131077570560",
#                 "indices": [
#                     75,
#                     98
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EFduUyvXsAAbCqL.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EFduUyvXsAAbCqL.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 2000,
#                         "resize": "fit",
#                         "w": 1457
#                     },
#                     "medium": {
#                         "h": 1200,
#                         "resize": "fit",
#                         "w": 874
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 495
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/0AVDuZmEfO"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 944742732,
#                 "id_str": "944742732",
#                 "indices": [
#                     24,
#                     37
#                 ],
#                 "name": "Escoles FEDAC",
#                 "screen_name": "EscolesFEDAC"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/0AVDuZmEfO",
#                 "expanded_url": "https://twitter.com/EscolesFEDAC/status/1177531138736345088/photo/1",
#                 "id": 1177531131077570560,
#                 "id_str": "1177531131077570560",
#                 "indices": [
#                     75,
#                     98
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EFduUyvXsAAbCqL.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EFduUyvXsAAbCqL.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 2000,
#                         "resize": "fit",
#                         "w": 1457
#                     },
#                     "medium": {
#                         "h": 1200,
#                         "resize": "fit",
#                         "w": 874
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 495
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/0AVDuZmEfO"
#             },
#             {
#                 "display_url": "pic.twitter.com/0AVDuZmEfO",
#                 "expanded_url": "https://twitter.com/EscolesFEDAC/status/1177531138736345088/photo/1",
#                 "id": 1177531131073314817,
#                 "id_str": "1177531131073314817",
#                 "indices": [
#                     75,
#                     98
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EFduUyuWwAEsjb2.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EFduUyuWwAEsjb2.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1023,
#                         "resize": "fit",
#                         "w": 1085
#                     },
#                     "medium": {
#                         "h": 1023,
#                         "resize": "fit",
#                         "w": 1085
#                     },
#                     "small": {
#                         "h": 641,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/0AVDuZmEfO"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 1177531138736345088,
#     "id_str": "1177531138736345088",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "ca",
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         2.052477,
#                         41.317048
#                     ],
#                     [
#                         2.052477,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.317048
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "country": "Espa\u00f1a",
#         "country_code": "ES",
#         "full_name": "Barcelona, Espa\u00f1a",
#         "id": "1a27537478dd8e38",
#         "name": "Barcelona",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/1a27537478dd8e38.json"
#     },
#     "possibly_sensitive": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "Avui #FridayForFuture a @escolesFEDAC #transFORMAdors #glocalitat #TUtopia https://t.co/0AVDuZmEfO",
#     "timestamp_ms": "1569580275602",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Mon Nov 12 22:53:10 +0000 2012",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Som una xarxa de 24 #escoles arreu de Catalunya amb el repte de transformar el sistema educatiu amb el projecte #avuixdem\u00e0. http://avuixdema.cat",
#         "favourites_count": 1935,
#         "follow_request_sent": null,
#         "followers_count": 2336,
#         "following": null,
#         "friends_count": 434,
#         "geo_enabled": true,
#         "id": 944742732,
#         "id_str": "944742732",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 46,
#         "location": "C/ dels \u00c0ngels, 18. Barcelona",
#         "name": "Escoles FEDAC",
#         "notifications": null,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/944742732/1552821310",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1049203477921128448/IT1_zSE3_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1049203477921128448/IT1_zSE3_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "EscolesFEDAC",
#         "statuses_count": 6813,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://fedac.cat",
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": {
#         "coordinates": [
#             2.1683,
#             41.3894
#         ],
#         "type": "Point"
#     },
#     "created_at": "Fri Sep 27 10:31:23 +0000 2019",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     42,
#                     48
#                 ],
#                 "text": "SEB19"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "instagram.com/p/B26VCIJC9hG/\u2026",
#                 "expanded_url": "https://www.instagram.com/p/B26VCIJC9hG/?igshid=1cjnjo19076rd",
#                 "indices": [
#                     72,
#                     95
#                 ],
#                 "url": "https://t.co/OeOthocUX5"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 436683103,
#                 "id_str": "436683103",
#                 "indices": [
#                     11,
#                     27
#                 ],
#                 "name": "SAL\u00d3N ER\u00d3TICO DE BARCELONA",
#                 "screen_name": "SALONEROTICOBCN"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": {
#         "coordinates": [
#             41.3894,
#             2.1683
#         ],
#         "type": "Point"
#     },
#     "id": 1177531171430981637,
#     "id_str": "1177531171430981637",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         2.052477,
#                         41.317048
#                     ],
#                     [
#                         2.052477,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.468266
#                     ],
#                     [
#                         2.229978,
#                         41.317048
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "country": "Espa\u00f1a",
#         "country_code": "ES",
#         "full_name": "Barcelona, Espa\u00f1a",
#         "id": "1a27537478dd8e38",
#         "name": "Barcelona",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/1a27537478dd8e38.json"
#     },
#     "possibly_sensitive": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#     "text": "See you at @saloneroticobcn October 3rd \ud83c\udfa4 #SEB19 xXx @ Barcelona, Spain https://t.co/OeOthocUX5",
#     "timestamp_ms": "1569580283397",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Apr 14 23:56:02 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "NON-BINARY Advocate for #GENDERISSUES. Communication, Styling, PR, Performer, Host. BUILDING A MORE INCLUSIVE WORLD \ud83c\udf0d",
#         "favourites_count": 213,
#         "follow_request_sent": null,
#         "followers_count": 708,
#         "following": null,
#         "friends_count": 1783,
#         "geo_enabled": true,
#         "id": 282312582,
#         "id_str": "282312582",
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 60,
#         "location": "London, England",
#         "name": "Joss Jaycoff",
#         "notifications": null,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/282312582/1542587384",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1176701311166926848/rnM_RQhS_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1176701311166926848/rnM_RQhS_normal.jpg",
#         "profile_link_color": "3B94D9",
#         "profile_sidebar_border_color": "5ED4DC",
#         "profile_sidebar_fill_color": "95E8EC",
#         "profile_text_color": "3C3940",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "JossJaycoff",
#         "statuses_count": 11218,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://www.instagram.com/jossjaycoff",
#         "utc_offset": null,
#         "verified": false
#     }
# }
# done

# %%
from tweepy import Stream,StreamListener

class listener(StreamListener):
    def __init__(self):
        super(StreamListener, self).__init__()
        self.num_tweets = 0
        
    def on_data(self, status):
        if self.num_tweets < 5:
            json_data=json.loads(status)
            print (str('** '+json_data["user"]["screen_name"])+' ** : ' + json_data["text"])
            self.num_tweets += 1
            return True
        else:
            return False
        
    def on_error(self, status):
        print (status)
        
# Catch all tweets in Barcelona area and print them
twitterStream = Stream(auth, listener()) 
twitterStream.filter(locations=[2.0504377635,41.2787636541,2.3045074059,41.4725622346])
print ("done")
# Out:
# ** fomenti ** : El precio de la #vivienda en #Barcelona cae por primera vez desde el 2013 https://t.co/1URj0lYB2m #RealEstate #Catalonia #Spain
# ** iMerrimantech ** : Going to go to the Apple store soon for the last time in Barcelona 😔 @NikiasMolina
# ** sanandoalmas ** : EL REIKI UNITARIO ES LO QUE UNE, NO LO QUE DIVIDE
#
# Muchas personas buscan toda clase de gurúes susceptibles de ofre… https://t.co/3mEORpucYY
# ** soulehoward1 ** : This meeting will clearly be my ESMO highlight! Thanks for the precious time and great conversation. Hopefully… https://t.co/vHNzXXhteZ
# ** andymstark ** : @LeeBinding https://t.co/mcf5JATq86
# done

# %% [markdown]
# Let us fill the class in order to capture and store the data in a MongoDB database.

# %%
from tweepy import Stream,StreamListener

class listener(StreamListener):
    def __init__(self):
        super(StreamListener, self).__init__()
        self.num_tweets = 0
        try:
            #use your database name, user and password here:
            #mongodb://<dbuser>:<dbpassword>@<mlab_url>/<database_name>
            with open("credentials.txt", 'r', encoding='utf-8') as f:
                [name,password,url]=f.read().splitlines()
                self.conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url,))
            print ("Connected successfully!!!")
        except pymongo.errors.ConnectionFailure as e:
            print ("Could not connect to MongoDB: %s" % e) 
        self.db = self.conn['API']
        self.collection = db['tweets']
    
    def on_data(self, status):
        if self.num_tweets < 5:
            jdata = json.loads(status)
            if 'android' in jdata["source"]:
                device = "android"
            else:
                device = "apple"
            document={'text':jdata["text"], 'created':jdata["created_at"], 'screen_name':jdata["user"]["screen_name"], 'device':device}        
            self.collection.insert_one(document) 
            print (document)
            self.num_tweets += 1
            return True
        else:
            return False
    
    def on_error(self, status):
        print (status)

# Catch all tweets in Barcelona area and print them
twitterStream = Stream(auth, listener()) 
twitterStream.filter(locations=[2.0504377635,41.2787636541,2.3045074059,41.4725622346])
print ("done")
# Out:
# Connected successfully!!!
# {'text': 'Participación tambien de Guillermo Trejo de @KelloggInst que nos habla de las múltiples violencias: "Mexico está en… https://t.co/EQLLd0OrCp', 'created': 'Fri Sep 27 10:37:00 +0000 2019', 'screen_name': 'ICIPeace', 'device': 'android', '_id': ObjectId('5d8de651f8125b02e0c915e3')}
# {'text': 'Els socialistes de #SantCugat i #Valldoreix ens sumem a la #VagaMundialPelClima #EmergenciaClimatica27S 👇🏻🌍', 'created': 'Fri Sep 27 10:37:07 +0000 2019', 'screen_name': 'Cugat_Psc', 'device': 'apple', '_id': ObjectId('5d8de658f8125b02e0c915e4')}
# {'text': '🙈🙈', 'created': 'Fri Sep 27 10:37:10 +0000 2019', 'screen_name': 'jordi_GT', 'device': 'apple', '_id': ObjectId('5d8de65bf8125b02e0c915e5')}
# {'text': "@siraesca És indignant!!!!\nLa premsa/TV és pensen fer l'agost empastifant-ho tot amb mentides.\nS'ha de denunciar.\nIntolerable i vergonyós!", 'created': 'Fri Sep 27 10:37:12 +0000 2019', 'screen_name': 'MontserratFig18', 'device': 'android', '_id': ObjectId('5d8de65df8125b02e0c915e6')}
# {'text': '@elmeropensador ✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️👍👍👍👍👍👍👍👍👍👍👍👍👏👏👏👏👏👏👏👏👏😘😘😘😘😘😘😘😘🤔🤗', 'created': 'Fri Sep 27 10:37:29 +0000 2019', 'screen_name': 'capodicampos', 'device': 'android', '_id': ObjectId('5d8de66ef8125b02e0c915e7')}
# done

# %%
#Check captured data https://cloud.mongodb.com

try:
    #use your database name, user and password here:
    #mongodb://<dbuser>:<dbpassword>@<mlab_url>/<database_name>
    with open("credentials.txt", 'r', encoding='utf-8') as f:
                [name,password,url]=f.read().splitlines()
                conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
except pymongo.errors.ConnectionFailure as e:
        print ("Could not connect to MongoDB: %s" % e) 

db = conn["API"]
collection = db['tweets']
print (collection.count_documents({}))
for doc in collection.find():
    print (str('** '+doc["screen_name"])+' ** : ' + doc["text"])
# Out:
# Connected successfully!!!
# 5
# ** ICIPeace ** : Participación tambien de Guillermo Trejo de @KelloggInst que nos habla de las múltiples violencias: "Mexico está en… https://t.co/EQLLd0OrCp
# ** Cugat_Psc ** : Els socialistes de #SantCugat i #Valldoreix ens sumem a la #VagaMundialPelClima #EmergenciaClimatica27S 👇🏻🌍
# ** jordi_GT ** : 🙈🙈
# ** MontserratFig18 ** : @siraesca És indignant!!!!
# La premsa/TV és pensen fer l'agost empastifant-ho tot amb mentides.
# S'ha de denunciar.
# Intolerable i vergonyós!
# ** capodicampos ** : @elmeropensador ✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️✌️👍👍👍👍👍👍👍👍👍👍👍👍👏👏👏👏👏👏👏👏👏😘😘😘😘😘😘😘😘🤔🤗

# %% [markdown]
# <div class = "alert alert-error" style = "border-radius:10px;border-width:3px;border-color:darkred;font-family:Verdana,sans-serif;font-size:16px;"> **EXERCISE:** Filter up to 5 twits with hashtag bigdata and location inside Barcelona province
# </div>

# %% [markdown]
# APIs are nice. Most large web site provide useful APIs, e.g. Google, OpenStreetMap, Facebook, etc, subject to some use terms. However most of the web sited do not provide any kind of access to data. What to do then?
