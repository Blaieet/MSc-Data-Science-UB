# %% [markdown]
# 1- **Twitter EXERCISE:**
#
# Given the starting user "eloipuertas", retrieve the user name, the date of the accoount creation and the last tweet date and text for each follower. Store them to a database called 'twitter' and into a collection called 'info'. The attributes of the document are: 'screen_name', 'created_at', 'last_tweet_text' and 'last_tweet_created_at'.

# %%
import json
import pymongo
import tweepy

try:
  
    with open("credentials.txt", 'r') as f:
        [name,password,url]=f.read().splitlines()
    conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 

db = conn['twitter']
collection = db.info


with open('APIKeys.txt', 'r') as f:
    [consumer_key,consumer_secret,access_key, access_secret]=f.read().splitlines()



#Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)


#Do something
USER_NAME = "eloipuertas"
user = api.get_user(id=USER_NAME)

for page in tweepy.Cursor(api.followers_ids, screen_name=USER_NAME).pages():
    for follower_id in page:
        last_tweet=api.user_timeline(id=follower_id,count=1)[0]
        last_tweet_date=api.user_timeline(id=follower_id,count=1)[0]
        follower = api.get_user(follower_id)
        print(last_tweet.text)
        print(last_tweet_date.created_at)
        print(follower.screen_name)
        print(follower.created_at)
        doc = {'screen_name': follower.screen_name,
                'created_at': follower.created_at,
               'last_tweet_text':last_tweet.text,
               'last_tweet_created_at':last_tweet_date.created_at
                
              }
        collection.insert_one(doc)

    time.sleep(5)
conn.close()
# Out:
# Connected successfully!!!
# We are pleased to announce our newest paper in the journal of Neuroimage: Clinical is now published online: https://t.co/HbnDjnDLoK
# 2020-09-17 14:10:25
# EmImagin
# 2019-11-08 14:44:41
# ¡Atención #mteUBA! Muy a tono con nuestro último seminario...💪😊@piaporota @ljsimonb @cinalvarezz @maxiperet… https://t.co/WElzB5aY4J
# 2020-10-21 12:06:49
# monserrat_pose
# 2016-10-15 10:25:24
# RT @FemlaPublicaUB: 🧍‍♂️🧍‍♀️Avui l’estudiantat sortim als carrers per la #Vaga21O.
#
# ✊ Organitzem-nos per fer front a la #CrisiEducativa i…
# 2020-10-21 11:38:32
# AMatesInfoUB
# 2020-10-07 21:01:52
# Aún martes 🙈🙈🙈🙈🙈🙈🙈🙈..vamosAello https://t.co/u63m9jQnyn
# 2020-09-24 06:51:53
# Carmen_62382
# 2009-03-25 04:25:41
# RT @ylecun: Using deep learning to find new compounds that can catalyze the production of hydrogen and fight climate change.
#
# An open resea…
# 2020-10-16 13:07:00
# javier_selvac
# 2020-08-24 14:40:16
# RT @PyBCN: 🔥 Candidatures obertes per la renovació de la Junta Directiva de PyBCN 🔥 Tots els socis estan convidats a presentar-se: https://…
# 2020-10-21 05:45:32
# b3r2s
# 2011-03-12 13:06:07
# @montsant_ @NandesHerr 😍
# 2020-10-16 20:35:34
# glosaycheese
# 2017-10-18 07:53:43
# RT @xavierbonal: Informe imprescindible publicado por #EurydiceEU sobre equidad en los sistemas educativos europeos. Evidencia actualizada…
# 2020-10-19 23:59:31
# AuraHdezSabate
# 2019-01-17 20:40:31
# RT @pablom_m: Grabado en Polonia. Majestuoso. Los gamos negros corren peligro debido a la caza. https://t.co/16PIgU4wgy
# 2020-10-21 09:09:42
# johnnync13
# 2015-08-18 23:03:53
# RT @cienciacarbonik: ¡Buenos días! Hoy nuestro compañero @ooliverdiaz de la @UniBarcelona nos trae una #carbonoticia sobre #TransformaciónD…
# 2020-10-09 08:56:28
# Postgrad_DT4H
# 2020-07-23 17:12:47
# الكلب يلي بدك تجرو عالصيد بلاه وبلا صيدو https://t.co/eRQO9tEO0m
# 2020-08-30 09:49:23
# 3bodee
# 2009-06-23 00:48:05
# https://t.co/A9vjlMBwSS
# 2020-09-25 12:13:22
# batx00
# 2020-06-02 13:47:33
# @polhinyo14 Les coses no es poden fer pitjor
# 2020-10-15 16:45:38
# lluismanuelg
# 2010-12-22 22:58:38
# RT @LuukvanderMeer: The evidence cannot be clearer: Google Street View causing COVID-19. #correlation #causation #conspiracy #COVID19 https…
# 2020-10-17 12:41:28
# luca_mw
# 2014-05-17 10:16:06
# RT @CIDUI_congress: (📢NOVETAT) Tots els números de la Revista #CIDUI es troben publicats al repositori de Revistes Catalanes amb Accés Ober…
# 2020-10-21 12:48:13
# eponsf
# 2010-02-22 10:21:08
# Avui EAP i veïnes hem tornat a sortir per demanar #CAPFortpiencJa. 12 anys esperant el @nou_cap a Gran Via. Barraco… https://t.co/P1CL2bqoIe
# 2020-10-21 13:42:42
# nou_cap
# 2020-06-12 09:52:33
# Muchas gracias s @Blog_Literario_ por haber reseñado mi primer libro. Es una satisfacción enorme que las palabras d… https://t.co/QGlNhmI8pc
# 2020-09-15 08:12:54
# SimonetMartinez
# 2020-05-13 15:01:13
# New blog post! Feeling a bit anxious about #AdvancedAnalytics implementations? Relax and take a look at how our “Pi… https://t.co/K5LhH1g1NV
# 2020-10-20 12:26:14
# CLEARPEAKS
# 2009-11-10 20:54:31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d25599782f96> in <module>
#      36         last_tweet=api.user_timeline(id=follower_id,count=1)[0]
#      37         last_tweet_date=api.user_timeline(id=follower_id,count=1)[0]
# ---> 38         follower = api.get_user(follower_id)
#      39         print(last_tweet.text)
#      40         print(last_tweet_date.created_at)
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# 2- **Selenium EXERCISE:**
# <ul>
# <li> Open a browser
#
# <li>Go to tripadvisor/Restaurants
#
# <li>Find the search text box
#
# <li>Clear it, input the query "Sant Cugat" and send it
#
# <li>Go to "Restarurants" and get the name and link of the top 10 restaurants in Sant cugat
# <li> Store them into a database called 'TripAdvisor' and a collection called 'Restaurants' with the documents atributes 'name' and 'link'
# </ul>
#
# </div>

# %%
import pymongo
import time
from selenium.webdriver.common.keys import Keys
try:
  

    with open("credentials.txt", 'r') as f:
        [name,password,url]=f.read().splitlines()
    conn=pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(name,password,url))
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 

db = conn['TripAdvisor']
collection = db.Restaurants

from selenium import webdriver
browser = webdriver.Chrome("chromedriver")
browser.get("https://www.tripadvisor.es/Restaurants")

element = browser.find_element_by_class_name("_3qLQ-U8m")
element.clear()
s='Sant Cugat'
element.send_keys(s)
button = browser.find_elements_by_xpath("//button[@type='submit' and @title='Buscar']")[0]
button.click()
time.sleep(5)
SCV= browser.find_elements_by_class_name("ui_columns")[8]
SCV.click()

browser.switch_to.window(browser.window_handles[-1])
browser.execute_script("window.scrollTo(0,document.body.scrollHeight/3)")

list_rest=browser.find_elements_by_class_name('_3S6pHEQs')[25:35]
for i in list_rest:
    link=i.get_attribute("href")
    attr=i.text
    names=attr.partition('\n')[0]
    doc = {
              'Name': names,
              'Link': link,
              }
    collection.insert_one(doc)
            
browser.quit()
conn.close()
# Out:
# Connected successfully!!!
