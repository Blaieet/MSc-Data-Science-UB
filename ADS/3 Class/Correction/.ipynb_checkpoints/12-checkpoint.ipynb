# %% [markdown]
# 1- **Twitter EXERCISE:**
#
# Given the starting user "eloipuertas", retrieve the user name, the date of the accoount creation and the last tweet date and text for each follower. Store them to a database called 'twitter' and into a collection called 'info'. The attributes of the document are: 'screen_name', 'created_at', 'last_tweet_text' and 'last_tweet_created_at'.

# %%
import json
import pymongo
import tweepy
import time

def get_last_user_tweet(user_id):
    status = api.user_timeline(user_id)
    return status

# Read twitter credentials
# with open('./twt_credentials.json') as f:
#     data = json.load(f)
    
with open('APIKeys.txt', 'r') as f:
    [consumer_key,consumer_secret,access_key, access_secret]=f.read().splitlines()

#--------------------------------------------------------------------------------
    
# Create the connection to MongoDB in local
try:
    conn=pymongo.MongoClient()
    print ("Connection to Mongo Daemon successful!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e)

# Create the "twitter" database and the "info" collection
db = conn["twitter"]
collection = db.info

#Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)


#Do something
USER_NAME = "eloipuertas"
user = api.get_user(id=USER_NAME)

screen_name = user.screen_name
created_at = user._json["created_at"]

#Retrieving all the followers
followers = []
for page in tweepy.Cursor(api.followers_ids, screen_name=USER_NAME).pages():
    followers.extend(page)
    time.sleep(5)  #This should be 60 to avoid limit rates

print("Storing users data...")

for follower in followers:
    follower_user = api.get_user(id=follower)
    
    # Check if the user is protected to avoid errors
    if follower_user.protected:
        pass
    else:
        # Check if there is any tweet in the account and then we store the data
        status = get_last_user_tweet(follower)
        if status:
            collection.insert_one({
                "screen_name": follower_user.screen_name,
                "created_at": follower_user._json["created_at"],
                "last_tweet_text": status[0].text,
                "last_tweet_created_at": str(status[0].created_at)
            })
        else:
            pass
        
print("Data stored!")
# Out:
# Connection to Mongo Daemon successful!!!
# Storing users data...
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-1-af56285780db> in <module>
#      59         status = get_last_user_tweet(follower)
#      60         if status:
# ---> 61             collection.insert_one({
#      62                 "screen_name": follower_user.screen_name,
#      63                 "created_at": follower_user._json["created_at"],
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# --> 613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     615                 bypass_doc_val, session)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600             _check_write_command_response(result)
#     601
# --> 602         self.__database.client._retryable_write(
#     603             acknowledged, _insert_command, session)
#     604
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1495     def _retryable_write(self, retryable, func, session):
#    1496         """Internal retryable write helper."""
# -> 1497         with self._tmp_session(session) as s:
#    1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1827             return
#    1828
# -> 1829         s = self._ensure_session(session)
#    1830         if s and close:
#    1831             with s:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1814             # Don't make implicit sessions causally consistent. Applications
#    1815             # should always opt-in.
# -> 1816             return self.__start_session(True, causal_consistency=False)
#    1817         except (ConfigurationError, InvalidOperation):
#    1818             # Sessions not supported, or multiple users authenticated.
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1764
#    1765         # Raises ConfigurationError if sessions are not supported.
# -> 1766         server_session = self._get_server_session()
#    1767         opts = client_session.SessionOptions(**kwargs)
#    1768         return client_session.ClientSession(
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1800     def _get_server_session(self):
#    1801         """Internal: start or resume a _ServerSession."""
# -> 1802         return self._topology.get_server_session()
#    1803
#    1804     def _return_server_session(self, server_session, lock):
#
# ~\anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     483                 if self._description.topology_type == TOPOLOGY_TYPE.Single:
#     484                     if not self._description.has_known_servers:
# --> 485                         self._select_servers_loop(
#     486                             any_server_selector,
#     487                             self._settings.server_selection_timeout,
#
# ~\anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     213             # No suitable servers.
#     214             if timeout == 0 or now > end_time:
# --> 215                 raise ServerSelectionTimeoutError(
#     216                     "%s, Timeout: %ss, Topology Description: %r" %
#     217                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it, Timeout: 30s, Topology Description: <TopologyDescription id: 5f904367364beade864de33f, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it')>]>

# %%
for x in collection.find({}, {"_id":0, "screen_name": 1, "created_at": 1, "last_tweet_text": 1, "last_tweet_created_at": 1}):  
    print(x)
# Out:
# {'screen_name': 'AMatesInfoUB', 'created_at': 'Wed Oct 07 21:01:52 +0000 2020', 'last_tweet_text': '📢Vaga 21-O⚠️\n\n📍 Concentració a Plaça Universitat\n⏰ 10:00h\n🦠 Mascareta i distància de seguretat\n\nOrganitzem-nos cont… https://t.co/LHngZTqD0r', 'last_tweet_created_at': '2020-10-19 14:05:01'}
# {'screen_name': 'Carmen_62382', 'created_at': 'Wed Mar 25 04:25:41 +0000 2009', 'last_tweet_text': 'Aún martes 🙈🙈🙈🙈🙈🙈🙈🙈..vamosAello https://t.co/u63m9jQnyn', 'last_tweet_created_at': '2020-09-24 06:51:53'}
# {'screen_name': 'javier_selvac', 'created_at': 'Mon Aug 24 14:40:16 +0000 2020', 'last_tweet_text': 'RT @ylecun: Using deep learning to find new compounds that can catalyze the production of hydrogen and fight climate change.\n\nAn open resea…', 'last_tweet_created_at': '2020-10-16 13:07:00'}
# {'screen_name': 'b3r2s', 'created_at': 'Sat Mar 12 13:06:07 +0000 2011', 'last_tweet_text': 'RT @littmath: "Empty sets are all alike; every non-empty set is non-empty in its own way."', 'last_tweet_created_at': '2020-10-18 07:17:14'}
# {'screen_name': 'glosaycheese', 'created_at': 'Wed Oct 18 07:53:43 +0000 2017', 'last_tweet_text': '@montsant_ @NandesHerr 😍', 'last_tweet_created_at': '2020-10-16 20:35:34'}
# {'screen_name': 'AuraHdezSabate', 'created_at': 'Thu Jan 17 20:40:31 +0000 2019', 'last_tweet_text': 'RT @PyLadiesMadrid: Nos vemos el sábado! 👋🐍💜', 'last_tweet_created_at': '2020-10-16 11:21:51'}
# {'screen_name': 'johnnync13', 'created_at': 'Tue Aug 18 23:03:53 +0000 2015', 'last_tweet_text': "I'm going to see transformers and it's not the film #NLP #BERT", 'last_tweet_created_at': '2020-10-19 17:06:59'}
# {'screen_name': 'Postgrad_DT4H', 'created_at': 'Thu Jul 23 17:12:47 +0000 2020', 'last_tweet_text': 'RT @cienciacarbonik: ¡Buenos días! Hoy nuestro compañero @ooliverdiaz de la @UniBarcelona nos trae una #carbonoticia sobre #TransformaciónD…', 'last_tweet_created_at': '2020-10-09 08:56:28'}
# {'screen_name': '3bodee', 'created_at': 'Tue Jun 23 00:48:05 +0000 2009', 'last_tweet_text': 'الكلب يلي بدك تجرو عالصيد بلاه وبلا صيدو https://t.co/eRQO9tEO0m', 'last_tweet_created_at': '2020-08-30 09:49:23'}
# {'screen_name': 'batx00', 'created_at': 'Tue Jun 02 13:47:33 +0000 2020', 'last_tweet_text': 'https://t.co/A9vjlMBwSS', 'last_tweet_created_at': '2020-09-25 12:13:22'}
# {'screen_name': 'lluismanuelg', 'created_at': 'Wed Dec 22 22:58:38 +0000 2010', 'last_tweet_text': '@polhinyo14 Les coses no es poden fer pitjor', 'last_tweet_created_at': '2020-10-15 16:45:38'}
# {'screen_name': 'luca_mw', 'created_at': 'Sat May 17 10:16:06 +0000 2014', 'last_tweet_text': 'RT @LuukvanderMeer: The evidence cannot be clearer: Google Street View causing COVID-19. #correlation #causation #conspiracy #COVID19 https…', 'last_tweet_created_at': '2020-10-17 12:41:28'}
# {'screen_name': 'eponsf', 'created_at': 'Mon Feb 22 10:21:08 +0000 2010', 'last_tweet_text': "RT @mrpStats: Encara sou a temps a participar al XX Dia de l'estadística. #IYWSDS #SoCE2020", 'last_tweet_created_at': '2020-10-19 19:11:22'}
# {'screen_name': 'nou_cap', 'created_at': 'Fri Jun 12 09:52:33 +0000 2020', 'last_tweet_text': 'RT @albasatorres: Els CAPS estem desbordats: necessitem coordinació real i efectiva amb scouts!! Scouts han de pertànyer a AP: pressupost d…', 'last_tweet_created_at': '2020-10-19 07:09:13'}
# {'screen_name': 'SimonetMartinez', 'created_at': 'Wed May 13 15:01:13 +0000 2020', 'last_tweet_text': 'Muchas gracias s @Blog_Literario_ por haber reseñado mi primer libro. Es una satisfacción enorme que las palabras d… https://t.co/QGlNhmI8pc', 'last_tweet_created_at': '2020-09-15 08:12:54'}
# {'screen_name': 'CLEARPEAKS', 'created_at': 'Tue Nov 10 20:54:31 +0000 2009', 'last_tweet_text': 'Join us for our webinar on October 28th and discover how you can bring Artificial Intelligence to #PowerBI! Registe… https://t.co/eItf33541f', 'last_tweet_created_at': '2020-10-19 08:38:35'}
# {'screen_name': 'lbadiella', 'created_at': 'Thu Dec 27 11:24:30 +0000 2012', 'last_tweet_text': 'RT @bcnanalytics: @AdevintaSpain We will have @bitenmascarado &amp; @alvaro_parafita presenting "Explainability with Causal Counterfactuals". A…', 'last_tweet_created_at': '2020-02-25 20:26:43'}
# {'screen_name': 'mguillen_estany', 'created_at': 'Thu Mar 24 19:30:21 +0000 2011', 'last_tweet_text': 'LSE talk today! I gave an Actuarial Science seminar and got great inputs! Thank you @LSEpublicevents @LSEnews https://t.co/6aRSyCocls', 'last_tweet_created_at': '2020-10-19 18:04:55'}
# {'screen_name': 'nlp_barcelona', 'created_at': 'Wed Feb 12 11:12:31 +0000 2020', 'last_tweet_text': 'RT @thammadou: “Google Open Sources a New Architecture for Massively Scalable Deep Reinforcement Learning” by @jrdothoughts\nhttps://t.co/zk…', 'last_tweet_created_at': '2020-03-29 21:54:34'}
# {'screen_name': 'ooliverdiaz', 'created_at': 'Mon May 11 18:10:29 +0000 2015', 'last_tweet_text': 'RT @jsantamariaglez: Ya está disponible el vídeo del webinar "Hacia la transformación de la #SaludDigital tras #COVID19", organizado por el…', 'last_tweet_created_at': '2020-10-19 15:27:17'}
# {'screen_name': 'PDellunde', 'created_at': 'Thu Jan 30 09:20:04 +0000 2020', 'last_tweet_text': 'RT @macips01: No s’ha entès res. Per reforçar la sanitat es treuen diners de la ciència, sense la qual la sanitat no pot superar crisis com…', 'last_tweet_created_at': '2020-06-14 05:51:06'}
# {'screen_name': 'Erola_Fenollosa', 'created_at': 'Fri Dec 30 11:09:52 +0000 2016', 'last_tweet_text': 'RT @GeografiaUB: Debat sobre model #superilles: "Ciutadania, dret i valor econòmic" organitzat pel @coacatalunya\n\n🗣️ Hi van participar tres…', 'last_tweet_created_at': '2020-10-17 16:25:25'}
# {'screen_name': 'PauRueQ', 'created_at': 'Tue Sep 11 14:09:48 +0000 2012', 'last_tweet_text': "RT @spacy_io: IT'S HERE! Today we're releasing spaCy nightly, the first candidate for the upcoming v3.0.\n\n🛸 Transformer-based pipelines for…", 'last_tweet_created_at': '2020-10-16 06:42:30'}
# {'screen_name': 'TonyHsu17', 'created_at': 'Thu Jul 09 02:19:56 +0000 2015', 'last_tweet_text': '@RevolutApp I cannot login to my app, can you help me solve this issue? is there anyway to contact you because I ca… https://t.co/ipxdZuCHB4', 'last_tweet_created_at': '2020-05-31 18:32:42'}
# {'screen_name': 'gatdelapena', 'created_at': 'Sun Jan 29 17:56:23 +0000 2012', 'last_tweet_text': "@pincfloit A mi no m'estima ni la @pincloit #faigmoltapena", 'last_tweet_created_at': '2020-09-28 07:18:28'}
# {'screen_name': 'eulaliamassana', 'created_at': 'Mon Feb 08 18:44:20 +0000 2010', 'last_tweet_text': "Marina Sabaté és l'@alumni_uvic @uvic_ucc  d'aquesta setmana. Tu sí que ets un àngel! 😉  https://t.co/mGcXW7oB58", 'last_tweet_created_at': '2020-10-16 05:30:32'}
# {'screen_name': 'AssembleaMates1', 'created_at': 'Mon Sep 30 22:19:51 +0000 2019', 'last_tweet_text': 'Vine a la primera assemblea de la teva facultat! https://t.co/tww8NKciRK', 'last_tweet_created_at': '2019-10-03 15:52:52'}
# {'screen_name': 'Sergideluna', 'created_at': 'Fri Nov 05 18:28:48 +0000 2010', 'last_tweet_text': '@LorenzoJoan Et recomano el All or Nothing: Tottenham Hotspur ;)', 'last_tweet_created_at': '2020-10-18 18:46:16'}
# {'screen_name': 'Pognioo', 'created_at': 'Sat Apr 12 21:10:29 +0000 2014', 'last_tweet_text': "RT @Fra7russo: 🤖Il progetto #MinervaBot sta facendo il giro dell'Italia!\n\n👉Minerva è un assistente virtuale nato con l'obiettivo di smentir…", 'last_tweet_created_at': '2020-04-17 12:23:14'}
# {'screen_name': 'InnovatEduc', 'created_at': 'Fri Nov 09 19:29:11 +0000 2012', 'last_tweet_text': 'RT @tic: 🥇🤖 #Bondia, avui el conseller @jordiPuignero, amb @joanabarbany, presidirà el lliurament de premis del #BitbotChallenge impulsat p…', 'last_tweet_created_at': '2020-10-19 07:10:54'}
# {'screen_name': 'scotthosking', 'created_at': 'Sat Jan 24 08:15:38 +0000 2009', 'last_tweet_text': 'RT @BillHareClimate: Queensland has the potential to draw all of its electricity from renewable sources in a 15-year transition away from f…', 'last_tweet_created_at': '2020-10-18 16:52:34'}
# {'screen_name': 'ColomeGemma', 'created_at': 'Tue Feb 23 19:34:31 +0000 2016', 'last_tweet_text': "RT @CatorzeCat: «Molta gent es passa tota la vida sense saber quins són els seus talents»\n\nL'educador Ken Robinson ha mort als 70 anys. En…", 'last_tweet_created_at': '2020-08-24 14:47:25'}
# {'screen_name': 'Franois36954471', 'created_at': 'Wed Jul 17 01:45:24 +0000 2019', 'last_tweet_text': '@LeeAnn_Hartford Hello Thank', 'last_tweet_created_at': '2019-08-13 19:16:04'}
# {'screen_name': 'mad_enrico', 'created_at': 'Tue Jan 03 17:31:55 +0000 2012', 'last_tweet_text': 'RT @Hacksterio: Powered by @Raspberry_Pi and @Arduino, this automated hydroponic system grows strawberries using @Grafana and @InfluxDB: ht…', 'last_tweet_created_at': '2020-09-11 22:27:14'}
# {'screen_name': 'GloryIsrael12', 'created_at': 'Tue Jul 02 21:24:57 +0000 2019', 'last_tweet_text': 'I WISH EVERYBODY HERE GOOD', 'last_tweet_created_at': '2019-07-02 21:31:53'}
# {'screen_name': 'monica_rius', 'created_at': 'Fri Feb 11 19:29:40 +0000 2011', 'last_tweet_text': 'Bona tarda, @ajsantpol hi ha algun servei de deixalleria mòbil? Gràcies!', 'last_tweet_created_at': '2020-10-19 16:40:49'}
# {'screen_name': 'SolerLali', 'created_at': 'Mon May 13 21:10:13 +0000 2013', 'last_tweet_text': 'Això dels quaranta és molt locu perquè tan aviat prenc copes i semblo de 20 com em marco un guisat que semblo la meva àvia.', 'last_tweet_created_at': '2020-10-18 16:43:05'}
# {'screen_name': 'eanton71', 'created_at': 'Wed Sep 14 09:23:37 +0000 2011', 'last_tweet_text': 'RT @Dani_Pellicer: Tú imagina que eres un neurólogo, te viene un chavalín universitario un poco cabezón con una migraña y al hacerle un esc…', 'last_tweet_created_at': '2020-10-19 14:07:05'}
# {'screen_name': 'gsas_io', 'created_at': 'Thu Jan 24 15:00:47 +0000 2019', 'last_tweet_text': 'RT @rebeccawb: We look forward to seeing you virtually next week! And for those who want to learn more about decision making practices, com…', 'last_tweet_created_at': '2020-10-15 08:32:59'}
# {'screen_name': 'Michael_qh', 'created_at': 'Mon Jul 15 17:18:12 +0000 2013', 'last_tweet_text': 'Trabajando ¬¬!!!', 'last_tweet_created_at': '2013-10-16 18:42:36'}
# {'screen_name': 'UnivXdrets', 'created_at': 'Mon Feb 18 17:23:31 +0000 2019', 'last_tweet_text': "RT @UPCxRepublica: L'estudiantat de @la_UPC també dóna suport als @sindics1octubre. Contents de continuar plegats en marxa per fer avançar…", 'last_tweet_created_at': '2020-10-19 18:49:39'}
# {'screen_name': 'pseudosane91', 'created_at': 'Mon Oct 30 15:11:31 +0000 2017', 'last_tweet_text': '@IWTKQuiz One wrist watch , for a team of 3', 'last_tweet_created_at': '2020-09-22 05:36:54'}
# {'screen_name': 'stuartmary6', 'created_at': 'Mon Mar 04 13:51:09 +0000 2019', 'last_tweet_text': '@FanaiTrey HI', 'last_tweet_created_at': '2019-03-19 02:52:44'}
# {'screen_name': 'AminZabardast', 'created_at': 'Thu Aug 28 16:46:51 +0000 2014', 'last_tweet_text': '@YesimSemchenko It does not taste bad or anything, but I could think of many other drinks I would order before I reach Pumpkin Spice 😅', 'last_tweet_created_at': '2020-10-08 05:36:52'}
# {'screen_name': 'RectorUB', 'created_at': 'Fri Sep 14 08:54:50 +0000 2018', 'last_tweet_text': 'Avui, #DiaMundialdelCàncerdeMama, us recomano seguir el web del Grup de #DonesUB, un grup de dones, treballadores d… https://t.co/9akg5LLp9Y', 'last_tweet_created_at': '2020-10-19 12:14:20'}
# {'screen_name': 'DataBarcelona', 'created_at': 'Tue Apr 26 14:58:31 +0000 2016', 'last_tweet_text': 'Open Computer Vision para p5.js y Processing \nby @ProcessingOrg  https://t.co/S3WjDmCgOg', 'last_tweet_created_at': '2020-10-12 14:30:56'}
# {'screen_name': 'scottknowles', 'created_at': 'Wed Sep 05 16:48:55 +0000 2007', 'last_tweet_text': 'https://t.co/BAIFfO6l4z', 'last_tweet_created_at': '2020-08-25 17:45:51'}
# {'screen_name': 'MaduixesAmbData', 'created_at': 'Thu Feb 07 19:45:00 +0000 2019', 'last_tweet_text': 'RT @dacfortuny: Hi! I hope everyone is safe at home. Next Tuesday I am talking in this online @AdevintaEng #Meetup with Carmen Herrero, I h…', 'last_tweet_created_at': '2020-04-05 08:50:27'}
# {'screen_name': 'stefanomelchior', 'created_at': 'Mon Nov 05 08:07:22 +0000 2007', 'last_tweet_text': 'Done ... long time ago!\nhttps://t.co/OmLjNGwmQx', 'last_tweet_created_at': '2020-10-12 15:27:39'}
# {'screen_name': 'NFagella', 'created_at': 'Thu May 14 06:47:57 +0000 2015', 'last_tweet_text': 'RT @MainatJM: Jordi Cuixart y Jordi Sánchez. \nTres años encarcelados. \nEs un buen momento para recordar estas palabras de @OwenJones84.\n#Ll…', 'last_tweet_created_at': '2020-10-17 15:16:38'}
# {'screen_name': 'mpsantolaria', 'created_at': 'Tue Oct 02 13:50:38 +0000 2018', 'last_tweet_text': 'RT @MrBlaid: Para estos días, para grandes y pequeños y para pasar un buen rato #Bones @jeffsmithsbone #comics #COVID19 #MeQuedoEnCasa #con…', 'last_tweet_created_at': '2020-03-27 12:54:32'}
# {'screen_name': 'pikatoteles', 'created_at': 'Fri Apr 23 13:11:58 +0000 2010', 'last_tweet_text': 'RT @DaniNovarama: Hoy les voy a contar que el otoño va a ser una mierda. Pero también les voy a contar que su otoño no tiene por qué ser un…', 'last_tweet_created_at': '2020-10-16 19:21:22'}
# {'screen_name': 'jcchavezs', 'created_at': 'Tue Dec 16 23:46:47 +0000 2008', 'last_tweet_text': 'Hi @Thundra is it a requirement to know how to read to be a CTO?', 'last_tweet_created_at': '2020-10-19 05:52:37'}
# {'screen_name': 'NadifiZineb', 'created_at': 'Mon Nov 05 13:27:32 +0000 2018', 'last_tweet_text': '#BigData', 'last_tweet_created_at': '2018-11-18 17:58:01'}
# {'screen_name': 'Bacaina3', 'created_at': 'Mon Sep 03 17:34:40 +0000 2018', 'last_tweet_text': 'RT @MatCAD_UAB: Un treball fet en part per professorat de la Facultat de Ciències de la UAB:\nQuantifying the non-reported new daily cases o…', 'last_tweet_created_at': '2020-03-21 16:59:03'}
# {'screen_name': 'MASSFOTON', 'created_at': 'Sat Apr 21 16:47:49 +0000 2018', 'last_tweet_text': 'UK Risks Losing Contract For New Climate Research Centre Because of Brexit: https://t.co/uliFBPGper', 'last_tweet_created_at': '2020-09-28 19:35:08'}
# {'screen_name': 'liopic', 'created_at': 'Mon Apr 06 08:34:32 +0000 2009', 'last_tweet_text': 'RT @DZPM: He recibido el libro digital "Python Basics: A Practical Introduction to Python 3": https://t.co/tPcMraAkj5\n\nPor suerte no lo nec…', 'last_tweet_created_at': '2020-10-18 10:21:19'}
# {'screen_name': 'joethebrew', 'created_at': 'Wed May 16 19:19:54 +0000 2018', 'last_tweet_text': '2019:\nLa Mesa del Congrés va suspendre el dret fonamental de sufragi passiu dels seus adversaris polítics utilitzan… https://t.co/KvVoHKC3BO', 'last_tweet_created_at': '2020-10-19 11:56:36'}
# {'screen_name': 'alexandre_nixon', 'created_at': 'Fri Mar 18 12:16:28 +0000 2011', 'last_tweet_text': '@TransitAeriBCN @mossos Per què????!!???', 'last_tweet_created_at': '2020-10-01 20:53:02'}
# {'screen_name': 'josepvives', 'created_at': 'Thu Mar 27 15:02:16 +0000 2008', 'last_tweet_text': '@jpurias @NetflixES @guillem_vives 👆👆', 'last_tweet_created_at': '2020-10-19 08:39:28'}
# {'screen_name': 'PagesTeresa', 'created_at': 'Tue Sep 25 21:49:06 +0000 2012', 'last_tweet_text': "RT @craibiologia: 🔓 Setmana de l'Accés Obert 2020 al @crai_ub de la UB\n\nDel 19 al 25 d'octubre se celebra l'Open Access Week 2020\n👉Notícia:…", 'last_tweet_created_at': '2020-10-17 10:05:09'}
# {'screen_name': 'ana_valdi', 'created_at': 'Fri May 06 14:44:51 +0000 2011', 'last_tweet_text': 'RT @SheaSwauger: When people ask me why I think higher ed should ban facial recognition, this is why', 'last_tweet_created_at': '2020-10-19 18:47:43'}
# {'screen_name': 'edugil39', 'created_at': 'Sun Jun 26 11:26:36 +0000 2011', 'last_tweet_text': '@GarmanSusi @Infermeres_ACDI @margaesteve La primera científica de dades era infermera :)', 'last_tweet_created_at': '2020-10-19 18:03:23'}
# {'screen_name': 'MaaSCatalonia', 'created_at': 'Tue Feb 06 21:07:56 +0000 2018', 'last_tweet_text': 'Only ubiquitous access to cars can replace (private) cars, by Hans Arby from @UbiGoMe #MaaS https://t.co/WqcMr0LwoW', 'last_tweet_created_at': '2020-10-18 10:38:55'}
# {'screen_name': '_arkeros', 'created_at': 'Wed Oct 19 17:52:43 +0000 2011', 'last_tweet_text': "RT @markdalgleish: It's a mistake to learn a framework without first learning the fundamentals. That's why, when dealing with beginners, I…", 'last_tweet_created_at': '2019-03-26 08:32:59'}
# {'screen_name': 'NoguerMiquel', 'created_at': 'Sat Jan 20 23:46:36 +0000 2018', 'last_tweet_text': 'Perque Españistan no és un projecte de res https://t.co/yCh4DTmbAf', 'last_tweet_created_at': '2020-10-19 19:35:59'}
# {'screen_name': 'BCN_ai', 'created_at': 'Wed Apr 18 09:53:04 +0000 2018', 'last_tweet_text': 'RT @ScottGottliebMD: This is GAME CHANGER. Abbott to market, starting next week, a fast point-of-care #coronavirus test, delivering positiv…', 'last_tweet_created_at': '2020-03-28 07:42:01'}
# {'screen_name': 'Xavier91vg', 'created_at': 'Thu Apr 21 19:30:53 +0000 2011', 'last_tweet_text': 'RT @memetiddies: This guy is in the wrong job 😂 https://t.co/4biieKsU5z', 'last_tweet_created_at': '2020-10-14 08:03:33'}
# {'screen_name': 'CireraAlbert', 'created_at': 'Thu Jun 07 22:09:13 +0000 2018', 'last_tweet_text': '@manguionduro @antoniobanos_ @antoniobanos_ si Tesla hubiera anunciado que iba a comprar las instalaciones de Nissa… https://t.co/eGKrR9xAn1', 'last_tweet_created_at': '2020-10-19 10:58:20'}
# {'screen_name': 'Ianrclark', 'created_at': 'Thu Nov 15 19:17:32 +0000 2007', 'last_tweet_text': 'RT @RealSpace3D: 3D renderings offer a zero contact alternative to open houses and show suites.\nhttps://t.co/UbqXMRcNIz', 'last_tweet_created_at': '2020-04-08 15:44:05'}
# {'screen_name': 'Gurnilogan', 'created_at': 'Thu Mar 18 19:14:28 +0000 2010', 'last_tweet_text': 'RT @DavidBbolton86: Imagine getting arrested... and then a cat sitting on you. https://t.co/7jTrhcBqpH', 'last_tweet_created_at': '2020-10-06 16:16:06'}
# {'screen_name': 'AISaturdays_ES', 'created_at': 'Sun Feb 18 22:18:51 +0000 2018', 'last_tweet_text': 'RT @SaturdaysAILP: ¡Estamos a horas de nuestra presentación de proyectos en el DEMO DAY!\nProyectos hechos usando algún modelo de IA para re…', 'last_tweet_created_at': '2020-10-17 09:56:46'}
# {'screen_name': 'Periquitoole', 'created_at': 'Sat Sep 23 16:47:48 +0000 2017', 'last_tweet_text': '@joseantich @elnacionalcat Que comediant , haver anat a  Montserrat  , i no desde el primer  moment demana disculpe… https://t.co/QyWfNFrlB0', 'last_tweet_created_at': '2020-10-08 12:00:29'}
# {'screen_name': 'CanodromBCN', 'created_at': 'Tue Dec 30 14:00:01 +0000 2014', 'last_tweet_text': 'RT @gamebcn: Ya iría siendo hora de que el gobierno de España impulse la industria del videojuego con buenas líneas de financiación a nivel…', 'last_tweet_created_at': '2020-10-08 21:27:39'}
# {'screen_name': 'montanom72', 'created_at': 'Thu Jun 17 12:18:37 +0000 2010', 'last_tweet_text': 'RT @tuSEAT: Los hay que seguro que no olvidan este mítico #SEAT. Diseñado por Giorgio Giugiaro, cambió la concepción del coche urbano en lo…', 'last_tweet_created_at': '2020-09-27 13:21:31'}
# {'screen_name': 'GOGPROD52', 'created_at': 'Mon Nov 21 22:38:52 +0000 2016', 'last_tweet_text': 'March to Glory', 'last_tweet_created_at': '2018-04-04 19:32:38'}
# {'screen_name': 'albertsanso', 'created_at': 'Fri Nov 27 20:58:10 +0000 2009', 'last_tweet_text': 'RT @MonTerrassa: 🏓 El CTT Els Amics #Terrassa (@ttamicsterrassa), reconegut com a centre formatiu i per a competicions oficials\n\nhttps://t.…', 'last_tweet_created_at': '2020-10-13 15:17:59'}
# {'screen_name': 'AliciaFornes', 'created_at': 'Tue Nov 01 17:36:19 +0000 2011', 'last_tweet_text': 'Moltes felicitats a les guanyadores!! #WomenInSTEM #DonaTIC https://t.co/kPEDt0AZtp', 'last_tweet_created_at': '2020-10-17 18:55:46'}
# {'screen_name': 'dtrinf', 'created_at': 'Thu Feb 02 13:22:09 +0000 2012', 'last_tweet_text': '@draentropia Eres project manager 😱', 'last_tweet_created_at': '2020-07-16 11:38:34'}
# {'screen_name': 'draentropia', 'created_at': 'Tue Aug 11 06:17:10 +0000 2009', 'last_tweet_text': '@Printzea ¿Tienes sitio para hacer unos drills con la espada larga o unos pasitos con la ropera?', 'last_tweet_created_at': '2020-10-19 18:11:07'}
# {'screen_name': 'albasatorres', 'created_at': 'Sun Jul 19 18:50:48 +0000 2009', 'last_tweet_text': 'RT @BGispert: La precària situació de l’#AtencióPrimària ens afecta a totes i tots, veïnxs, treballadorxs, comunitat i ciutadania en genera…', 'last_tweet_created_at': '2020-10-19 18:37:18'}
# {'screen_name': 'PaulBanks84', 'created_at': 'Sun Nov 09 15:06:32 +0000 2014', 'last_tweet_text': 'Confirmed cases in the last 7 days per 100,000 people. https://t.co/NwTP7q3GwQ https://t.co/kuqnyLjM8Y', 'last_tweet_created_at': '2020-10-19 19:30:32'}
# {'screen_name': 'Junior_ochei', 'created_at': 'Sat Feb 19 12:04:22 +0000 2011', 'last_tweet_text': '@Jlaudio2 Pues según leí cuanto más grande lo tengan menos sienten. Es decir, cuanto más pequeño es el clítoris ten… https://t.co/Gd6BJuKHFa', 'last_tweet_created_at': '2020-01-24 18:32:50'}
# {'screen_name': 'khan5alman', 'created_at': 'Wed Mar 29 22:58:59 +0000 2017', 'last_tweet_text': 'Check it out! khan5alman will run an effective facebook ad campaign for you for $5 on #Fiverr https://t.co/6h0k5fcCy0', 'last_tweet_created_at': '2018-05-10 05:00:04'}
# {'screen_name': 'IRBioUB', 'created_at': 'Mon Apr 24 08:46:33 +0000 2017', 'last_tweet_text': 'RT @AMacedaVeiga: ¿Buscas FPI para una tesis? Mis 2 consejos en lo personal, ciencia aparte, son: 1) habla con exdoctorandos/TFMs de tu sup…', 'last_tweet_created_at': '2020-10-19 17:25:34'}
# {'screen_name': 'speaso', 'created_at': 'Mon May 03 09:46:23 +0000 2010', 'last_tweet_text': 'RT @Esri_Spain: 🌍Esri, @GrupoAIS e @iSostenibilidad hemos lanzamos #ODSMaps, una solución para ayudar a los ayuntamientos a conseguir los 1…', 'last_tweet_created_at': '2020-10-19 17:44:10'}
# {'screen_name': 'Dani_GaTe', 'created_at': 'Thu Oct 30 02:09:38 +0000 2014', 'last_tweet_text': 'RT @neiltyson: You can’t use reason to convince anyone out of an argument that they didn’t use reason to get into.', 'last_tweet_created_at': '2020-10-11 21:38:19'}
# {'screen_name': 'slopiano', 'created_at': 'Tue Sep 09 08:21:55 +0000 2014', 'last_tweet_text': '@architecturehub Well, even Grosseto - not so far away https://t.co/sqjoTfeWAu', 'last_tweet_created_at': '2020-10-18 07:45:35'}
# {'screen_name': 'estepi', 'created_at': 'Tue Jul 24 01:35:36 +0000 2007', 'last_tweet_text': 'RT @the_prbb: Ya habéis echado un vistazo a la web del #openPRBB? Aquí os invitamos a un paseo por todos los contenidos \nRecordad apuntaros…', 'last_tweet_created_at': '2020-10-16 16:29:25'}
# {'screen_name': 'zfalomir', 'created_at': 'Tue Jan 24 22:11:59 +0000 2012', 'last_tweet_text': 'RT @maitels: https://t.co/mp0gnMXN3s  Les dades obertes i la intel·ligència artificial, eines per a la igualtat de gènere', 'last_tweet_created_at': '2020-10-19 09:14:20'}
# {'screen_name': 'IIIAdivulga', 'created_at': 'Fri Nov 28 11:07:49 +0000 2008', 'last_tweet_text': 'Feina: https://t.co/I4hEwi7pZ6 https://t.co/4XobYHvegQ', 'last_tweet_created_at': '2020-07-17 11:10:02'}
# {'screen_name': 'PaddySynge', 'created_at': 'Fri Aug 02 13:07:50 +0000 2013', 'last_tweet_text': 'RT @RobotUnion_EU: We have the first #RobotUnion winners selected at the #JuryDay_RU18:\nACCREA Bartlomiej Stanczyk\nAivero AS\nAlias Robotics…', 'last_tweet_created_at': '2018-09-14 13:42:58'}
# {'screen_name': 'FacPsicoUB', 'created_at': 'Wed Apr 11 09:59:03 +0000 2012', 'last_tweet_text': 'Ho sabíeu? 👇 https://t.co/wMAESg67zV', 'last_tweet_created_at': '2020-10-18 07:04:09'}
# {'screen_name': 'EliportRobots', 'created_at': 'Fri Oct 06 08:52:34 +0000 2017', 'last_tweet_text': 'Dmitry Skorinko at traffiX + logistiX Innovation Forum @MunichNetwork https://t.co/wUTilu4got', 'last_tweet_created_at': '2019-05-28 15:43:47'}
# {'screen_name': 'acia_cat', 'created_at': 'Mon Oct 26 14:28:58 +0000 2015', 'last_tweet_text': 'RT @UdGSmartHealth: Congratulations!', 'last_tweet_created_at': '2020-10-16 11:16:15'}
# {'screen_name': 'granvilleDSC', 'created_at': 'Tue Aug 01 17:56:35 +0000 2017', 'last_tweet_text': 'Digital Transformations in the Post-Covid World https://t.co/a25h48x6bW', 'last_tweet_created_at': '2020-10-19 19:00:36'}
# {'screen_name': 'jordireixah', 'created_at': 'Thu Jun 17 13:42:42 +0000 2010', 'last_tweet_text': '@UkuMon_ Me encanta la taza!, Como te puedk hacer el encargo?', 'last_tweet_created_at': '2020-08-16 09:55:03'}
# {'screen_name': 'AinaPascualC', 'created_at': 'Mon Mar 21 10:12:25 +0000 2011', 'last_tweet_text': 'RT @Hoeller: Thanks @JanPhilippBeck, this MoU with @ubiglobal is indeed an important partnership milestone for @EITHealth and our partner #…', 'last_tweet_created_at': '2019-03-25 20:53:48'}
# {'screen_name': 'ferranmorales', 'created_at': 'Wed May 18 23:16:22 +0000 2011', 'last_tweet_text': 'RT @infografiaMD: 📰#ReportajeMD\nBig Three: La carrera entre @RafaelNadal, @rogerfederer y @DjokerNole para ser el mejor de la historia, en…', 'last_tweet_created_at': '2020-10-19 17:51:28'}
# {'screen_name': 'montsegorchsm', 'created_at': 'Tue Feb 01 11:09:35 +0000 2011', 'last_tweet_text': 'RT @iriscarla2001: @mecs_ub @tinoperez9 @Raulaveiro @alvarocv131 @sanz_miquel Carla Prudencio. La situación actual de hoy, (pandemia) nos a…', 'last_tweet_created_at': '2020-10-19 19:00:37'}
# {'screen_name': 'Cesc537', 'created_at': 'Fri Aug 27 16:55:02 +0000 2010', 'last_tweet_text': "RT @ERC_dones: 💜Avui, 19 d'octubre, és el #DiaContraelCancerdeMama \nActualment, el càncer de mama és el més freqüent en dones. Detectar-ho…", 'last_tweet_created_at': '2020-10-19 07:23:29'}
# {'screen_name': 'Raulmuto', 'created_at': 'Sun Oct 31 14:01:25 +0000 2010', 'last_tweet_text': 'RT @vicepresicat: 📸El #vicepresident @perearagones i la consellera de salut @albaverges visiten l’Hospital de Palamós per explicar les mill…', 'last_tweet_created_at': '2020-10-18 20:16:05'}
# {'screen_name': 'AlejandroCano94', 'created_at': 'Tue May 03 21:13:30 +0000 2011', 'last_tweet_text': 'RT @ymouled: Mujer llorando le dice al agente de Policía Nacional que la esposa: "Estoy embarazada". El agente continúa con un puñetazo en…', 'last_tweet_created_at': '2020-10-19 14:59:44'}
# {'screen_name': 'anaisgarrell', 'created_at': 'Tue Jul 06 21:10:21 +0000 2010', 'last_tweet_text': '@mianrey @lavecinarubia Pero también lo mejor de muchas personas. Intentemos centrarnos en esto. Animo @lavecinarubia', 'last_tweet_created_at': '2020-10-13 08:03:20'}
# {'screen_name': 'hackcancer_data', 'created_at': 'Mon Feb 05 13:35:29 +0000 2018', 'last_tweet_text': 'Gaur @garanet egunkarian gaude. Portadan eta guzti! #hackcancer #hackcancer2018 #hackcancerdonostia… https://t.co/recUePNIkH', 'last_tweet_created_at': '2018-06-14 06:55:17'}
# {'screen_name': 'speremateu', 'created_at': 'Thu Mar 11 09:10:39 +0000 2010', 'last_tweet_text': 'Mediaset España: CARTA ABIERTA A CUATRO Y MEDIASET, CIERRE DE MALAS PULGAS - ¡Firma la petición!… https://t.co/9a8Q6xld33', 'last_tweet_created_at': '2019-03-12 21:41:00'}
# {'screen_name': 'ushba_sliabh', 'created_at': 'Fri Jun 10 19:36:27 +0000 2016', 'last_tweet_text': 'RT @repoblem: EMPRENEDORS📢\n\nAl Ripollès es TRASPASSA gelateria. \n\nLa cessió inclou la maquinària i la utilització de la marca "La Recuiteri…', 'last_tweet_created_at': '2020-10-19 04:58:17'}
# {'screen_name': 'smuria', 'created_at': 'Mon Jul 06 12:54:14 +0000 2009', 'last_tweet_text': 'RT @C2EM2020: Us presentem una versió digital del cub símbol del nostre Congrés. \nAgraïm especialment a @dment37 i @bancoche la seva creaci…', 'last_tweet_created_at': '2020-10-19 14:36:39'}
# {'screen_name': 'CIDUI_congress', 'created_at': 'Tue Sep 20 19:28:18 +0000 2011', 'last_tweet_text': '(📢NOVETAT) Tots els números de la Revista #CIDUI es troben publicats al repositori de Revistes Catalanes amb Accés… https://t.co/EhLZgAqkM9', 'last_tweet_created_at': '2020-10-19 11:44:23'}
# {'screen_name': 'AimirAbogados', 'created_at': 'Wed Jan 24 08:37:57 +0000 2018', 'last_tweet_text': 'RT @ToscaniDaniel: ¿Qué debo firmar en un finiquito? Si sólo es la entrega de una cantidad de dinero y te lo entregan, puedes firmar recibi…', 'last_tweet_created_at': '2020-10-18 16:07:11'}
# {'screen_name': 'databeersMDE', 'created_at': 'Sun Jun 05 18:02:25 +0000 2016', 'last_tweet_text': 'Datos, no opiniones. https://t.co/SbMrVGb2xn', 'last_tweet_created_at': '2018-12-30 02:42:46'}
# {'screen_name': 'epuigbordera', 'created_at': 'Tue Mar 04 11:13:13 +0000 2014', 'last_tweet_text': 'RT @perearagones: Amb aquesta sentència pretenen condemnar la democràcia i el debat parlamentari. Una aberració més en la repressió. Però n…', 'last_tweet_created_at': '2020-10-19 16:24:41'}
# {'screen_name': 'onestepbeyong', 'created_at': 'Sun Sep 06 19:32:39 +0000 2015', 'last_tweet_text': 'Si, no calleu, exigiu! Demaneu! https://t.co/e6HrgZkQ2g', 'last_tweet_created_at': '2020-10-19 19:13:24'}
# {'screen_name': 'S_RuedaM', 'created_at': 'Fri Jan 06 17:16:41 +0000 2012', 'last_tweet_text': '@BCN_Mobilitat Muy pesados con bicicletas y patinetes. El control está bien pero se debe incentivar modos alternati… https://t.co/QSbnZcexyL', 'last_tweet_created_at': '2019-11-22 14:44:45'}
# {'screen_name': 'lucacerone', 'created_at': 'Sat Aug 29 11:26:48 +0000 2009', 'last_tweet_text': '@snorl4x @adriav @adriav @snorl4x cada vez que escribís "pizza Barcelona" un niño en Italia llora :) pero espero el… https://t.co/gwWhdpJSeD', 'last_tweet_created_at': '2020-09-17 05:09:39'}
# {'screen_name': 'x3deeh', 'created_at': 'Fri Oct 16 00:50:37 +0000 2009', 'last_tweet_text': 'Daily briefing: Huge COVID trial finds ‘little or no effect’ for remdesivir https://t.co/eqfTSFypjY https://t.co/XSCfseAzii', 'last_tweet_created_at': '2020-10-19 16:29:33'}
# {'screen_name': 'ScienceSlam_de', 'created_at': 'Thu Oct 05 08:24:43 +0000 2017', 'last_tweet_text': 'Folgt doch auch gern mal unserem @sciencepubquiz Account ... https://t.co/NjGlCtR1kD', 'last_tweet_created_at': '2018-11-13 07:31:59'}
# {'screen_name': 'dipina', 'created_at': 'Wed Aug 26 05:40:56 +0000 2009', 'last_tweet_text': 'RT @B_I_G_1_: Today is the big day......#EDIDatathon2020 @edincubator.\nWe are going to present the project and our #Geomarketing to the Tec…', 'last_tweet_created_at': '2020-10-19 15:08:15'}
# {'screen_name': 'AdrianM_Torre', 'created_at': 'Thu Jun 17 19:49:34 +0000 2010', 'last_tweet_text': '@rafalab @midnucas @hortizzuazaga @Sefini @DaniloTPerez @portna @MeliMarz Muchas gracias!', 'last_tweet_created_at': '2020-09-28 18:21:30'}
# {'screen_name': 'mercemasana', 'created_at': 'Fri May 27 10:37:15 +0000 2011', 'last_tweet_text': "RT @CampusClinicUB: ⚠️Alumnat del #CampusClínicUB⚠️\n\n➡️Recordeu que a partir d'avui dia 15 i fins el 30 d'octubre, entren en vigor les norm…", 'last_tweet_created_at': '2020-10-16 07:07:01'}
# {'screen_name': 'Dani_Gambit', 'created_at': 'Sat Apr 21 15:16:03 +0000 2012', 'last_tweet_text': "RT @AlleracNicola: quanto cazzo pagherei per sapere tra quindici giorni cosa griderete dai balconi...\n\n(nulla perché non c'ho na lira ma ad…", 'last_tweet_created_at': '2020-10-14 23:45:21'}
# {'screen_name': 'serrjoa', 'created_at': 'Sun Sep 27 11:48:31 +0000 2015', 'last_tweet_text': 'RT @GuillaumeLample: Last year, we showed that you can outperform a 24-layer transformer in language modeling with just 12 layers and 1 Pro…', 'last_tweet_created_at': '2020-10-18 11:06:21'}
# {'screen_name': 'LearnDataSciece', 'created_at': 'Mon Sep 25 08:36:09 +0000 2017', 'last_tweet_text': 'Python Programming Full Course (Basics,OOP,Modules,PyQt)\n☞ https://t.co/YK1y3TCp9A\n#DataScience #Bigdata\nSJ2V9O4Lf https://t.co/fx4orOLHxE', 'last_tweet_created_at': '2018-02-06 09:29:48'}
# {'screen_name': 'martoesp', 'created_at': 'Tue Dec 30 13:10:06 +0000 2014', 'last_tweet_text': 'RT @xaviermartinezg: Potser els ciutadans no són conscients que milers de treballadors públics de la Generalitat fa mesos que treballem des…', 'last_tweet_created_at': '2020-10-18 14:48:54'}
# {'screen_name': 'CDRSantPere', 'created_at': 'Tue Nov 07 09:30:59 +0000 2017', 'last_tweet_text': "🔈l'Assemblea del CDR Sant Pere canvia de dia de manera excepcional!\n\n📆 Dijous\n⏰ 20h00\n📍 Local de la AV de l'Antic Poble de St Pere", 'last_tweet_created_at': '2019-01-15 07:53:45'}
# {'screen_name': 'rdelavega', 'created_at': 'Mon Feb 04 22:03:58 +0000 2008', 'last_tweet_text': 'RT @janetsanz: La contaminació mata 1.000 persones cada any a Barcelona segons els experts de @salutpublicabcn.\n\nLa reducció del trànsit és…', 'last_tweet_created_at': '2020-10-19 14:57:55'}
# {'screen_name': 'jorditarradas', 'created_at': 'Mon Oct 19 16:00:56 +0000 2009', 'last_tweet_text': "RT @cpforestal: El @DOGCdeldia publica avui l'ampliació de dotació pressupostària dels #ajuts a la gestió forestal sostenible en finques de…", 'last_tweet_created_at': '2020-10-19 12:44:34'}
# {'screen_name': 'enricsaes', 'created_at': 'Tue Nov 22 11:23:25 +0000 2011', 'last_tweet_text': 'RT @Lafede_cat: Gràcies #Quino per ajudar-nos a pensar i ensenyar-nos a educar en la solidaritat i la llibertat. \n#QuinoPorSiempre https://…', 'last_tweet_created_at': '2020-10-01 05:27:50'}
# {'screen_name': 'beloki79', 'created_at': 'Mon Dec 30 18:24:38 +0000 2013', 'last_tweet_text': '@PhenomenaExp Veo que habéis quitado La Naranja Mecánica de la programación de mañana, verdad? Los  que tenemos la… https://t.co/eixNVtwDKx', 'last_tweet_created_at': '2020-10-16 12:19:05'}
# {'screen_name': 'laia_soriano', 'created_at': 'Wed May 25 12:26:09 +0000 2011', 'last_tweet_text': '@Viktormarther Per molts anys, Víctor!', 'last_tweet_created_at': '2020-10-15 14:14:01'}
# {'screen_name': 'datalesdatales', 'created_at': 'Thu Nov 23 22:26:30 +0000 2017', 'last_tweet_text': 'On A/A tests, p-values, significance, and the uniform distribution, by @adrialuz https://t.co/YChvJmONn3', 'last_tweet_created_at': '2020-10-14 10:13:05'}
# {'screen_name': 'jordi_ballart', 'created_at': 'Sat Jan 01 22:17:29 +0000 2011', 'last_tweet_text': "@joanpinol13 @ajterrassa Bona nit Jordi, lamento molt la situació que s'ha generat. T'agrairé enviïs aquesta incidè… https://t.co/2zw1aKEyCw", 'last_tweet_created_at': '2020-10-19 19:09:07'}
# {'screen_name': 'carlescasac', 'created_at': 'Sun Sep 21 12:25:46 +0000 2014', 'last_tweet_text': 'Som molta gent que fem i farem costat als @sindics1octubre #Sindics1OAbsolucio https://t.co/muxwQ2kKpm', 'last_tweet_created_at': '2020-10-15 16:08:23'}
# {'screen_name': 'm_a_upson', 'created_at': 'Wed May 01 10:27:26 +0000 2013', 'last_tweet_text': "@DanHLawReporter Will be soon! I'll drop you a line once I get out of quarantine!", 'last_tweet_created_at': '2020-10-19 13:53:55'}
# {'screen_name': 'lovelymaps_', 'created_at': 'Thu Oct 27 13:55:50 +0000 2016', 'last_tweet_text': "Vols formar part de lovelymaps? Si ets front-end developer mira't la proposta \nhttps://t.co/3r1fhxNp6T", 'last_tweet_created_at': '2019-06-19 12:15:09'}
# {'screen_name': 'upc_acm', 'created_at': 'Thu Aug 10 10:19:55 +0000 2017', 'last_tweet_text': 'We are all really excited about this new project @BCN_ai', 'last_tweet_created_at': '2018-06-01 20:45:43'}
# {'screen_name': 'Viktormarther', 'created_at': 'Sun Jul 31 19:55:19 +0000 2011', 'last_tweet_text': '@jordi_olot Ohhh!', 'last_tweet_created_at': '2020-10-19 10:05:26'}
# {'screen_name': 'CaiClone1013', 'created_at': 'Sat Dec 03 16:12:19 +0000 2016', 'last_tweet_text': 'RT @fansubscat: Nova notícia de @LlPnF: «[Manga] Mushishi - 13»\nhttps://t.co/MxhUbNKz7s', 'last_tweet_created_at': '2020-07-02 23:11:15'}
# {'screen_name': 'sinapticasblog', 'created_at': 'Tue Oct 31 19:19:34 +0000 2017', 'last_tweet_text': 'Will the future of EEG measurement be with tattoos? https://t.co/NW8lhtqcXF @sinapticasblog #eeg #neurotech #bci #neuroscience', 'last_tweet_created_at': '2020-10-09 19:49:30'}
# {'screen_name': 'apages1977', 'created_at': 'Tue Jul 07 08:37:55 +0000 2015', 'last_tweet_text': 'RT @EduardBiosca: @XSalaimartin I amb vídeos que evidencien (mirant qui surt i qui NO) que el rei divideix clarament als espanyols. Quan la…', 'last_tweet_created_at': '2020-10-13 20:56:54'}
# {'screen_name': 'Raspberry_Pi_2', 'created_at': 'Sat Dec 05 16:42:01 +0000 2015', 'last_tweet_text': 'Tutorial RaspberryPi - 11. Cómo instalar JAVA https://t.co/JJrLAigW7p', 'last_tweet_created_at': '2020-10-19 17:40:10'}
# {'screen_name': 'montse_ro_pa', 'created_at': 'Sun Oct 09 10:17:33 +0000 2011', 'last_tweet_text': '#COEBIGDATA17 muy interesante! Ei, ojo lenguaje sexista. Las mujeres también compramos coches,somos científicas... Nos ayudamos tod@s?', 'last_tweet_created_at': '2017-10-25 09:19:35'}
# {'screen_name': 'XeviGuitart', 'created_at': 'Sun Feb 06 21:32:22 +0000 2011', 'last_tweet_text': 'RT @AnnaBosCam: @david_meldor A nosaltres, també a Sants, han trigat des de dimecres passat fins a avui a fer la PCR a un grup confinat que…', 'last_tweet_created_at': '2020-09-28 20:58:05'}
# {'screen_name': 'OssetMarti', 'created_at': 'Thu Sep 27 07:29:42 +0000 2012', 'last_tweet_text': 'RT @MarcaBasket: 🏀💵 Sue Bird-LeBron James: La comparativa salarial que ha incendiado las redes\n#NBA #WNBA\nhttps://t.co/kqsrGE4GRc https://t…', 'last_tweet_created_at': '2020-10-18 13:04:55'}
# {'screen_name': 'AnnaForastier', 'created_at': 'Thu Feb 18 17:06:18 +0000 2010', 'last_tweet_text': 'RT @squadrado: ➡️La capital absorbe y atrae no sólo la actividad empresarial, sino el talento y el grueso de la Administración en detriment…', 'last_tweet_created_at': '2020-10-18 20:01:16'}
# {'screen_name': 'blauigris', 'created_at': 'Fri Oct 20 09:57:38 +0000 2017', 'last_tweet_text': 'RT @cgarciae88: Lambda Networks: SOTA on ImageNet.  Again Transformer-like architectures dominating over a new field 🚀.  CNNs had a good ru…', 'last_tweet_created_at': '2020-10-19 06:36:52'}
# {'screen_name': 'CianOnData', 'created_at': 'Mon Sep 14 08:54:54 +0000 2015', 'last_tweet_text': 'Is there a danger of making advanced models like deep learning available to non-experts who can apply the algorithm… https://t.co/klc154A06I', 'last_tweet_created_at': '2018-10-02 08:54:08'}
# {'screen_name': 'CrisSsaura', 'created_at': 'Mon Sep 07 10:13:24 +0000 2015', 'last_tweet_text': 'RT @jccalbet: Potser ha passat desapercebut, però els jugadors del Barça de bàsquet Pierre Oriola, Alex Abrines i Sergi Martinez han jugat…', 'last_tweet_created_at': '2020-10-16 11:10:13'}
# {'screen_name': 'mikelvives', 'created_at': 'Sun Nov 22 22:07:03 +0000 2009', 'last_tweet_text': "RT @anoiadiari: A #IGUALADA hi haurà tres punts alternatius de vacunació: el Casal de Montserrat, l'Escorxador i el Casal del Passeig Verda…", 'last_tweet_created_at': '2020-10-19 18:55:35'}
# {'screen_name': 'ismansiete', 'created_at': 'Mon Mar 21 14:05:26 +0000 2011', 'last_tweet_text': 'RT @AnneInRohan: Lo ví y necesito compartirlo https://t.co/sXWY3A3g2b', 'last_tweet_created_at': '2020-10-19 17:51:14'}
# {'screen_name': 'ProfTurismo', 'created_at': 'Thu Nov 18 09:29:48 +0000 2010', 'last_tweet_text': 'Las agencias de viaje del Reino Unido destacan la estrategia sostenible de Valencia https://t.co/H8gWLeorrP https://t.co/OZf3YfSr1D', 'last_tweet_created_at': '2020-10-19 10:56:35'}
# {'screen_name': 'tecno_lord', 'created_at': 'Thu Jul 06 15:18:12 +0000 2017', 'last_tweet_text': 'RT @AlexCorvis84: Si quieres aprender 🤓 electrónica y circuitos ⚡️, echa un vistazo a esta Web \n\nhttps://t.co/0NWoN3eGNw https://t.co/YlK4Q…', 'last_tweet_created_at': '2020-08-20 06:50:45'}
# {'screen_name': 'adrian_dp_', 'created_at': 'Thu Sep 08 13:33:37 +0000 2011', 'last_tweet_text': '@xavifar @alvnicolas @bcnencomu @BCN_Mobilitat @mvidal80 @EnbicixBCN Com pot ser que els percentatges de 2011 sumin 92% i al 2016 100,2% ? 🤨', 'last_tweet_created_at': '2019-03-10 12:56:50'}
# {'screen_name': 'cgarciapedraza9', 'created_at': 'Sat Dec 21 23:22:08 +0000 2013', 'last_tweet_text': '@Gerard_MazBu Paco,paquito,poco paquete....', 'last_tweet_created_at': '2018-08-28 13:12:26'}
# {'screen_name': 'XES_Terrassa', 'created_at': 'Sat Mar 28 14:43:17 +0000 2015', 'last_tweet_text': 'RT @fiareBE: La @ffinanzaseticas ha seleccionado 20 proyectos financiados por @fiareBE y entidades miembros de #REFAS 🐝 que recibirán los f…', 'last_tweet_created_at': '2020-09-03 17:49:03'}
# {'screen_name': 'EchevarriaCarme', 'created_at': 'Thu Dec 29 19:24:59 +0000 2016', 'last_tweet_text': 'RT @peresimon93: Espanya segueix ingovernable. Ens veiem als carrers! @tsunami_dem', 'last_tweet_created_at': '2019-11-11 07:08:02'}
# {'screen_name': 'mireia_besalu', 'created_at': 'Wed Jul 19 11:03:43 +0000 2017', 'last_tweet_text': 'RT @AlbanoDante76: Gràcies @QuimTorraiPla per no treure la pancarta.\nhttps://t.co/UZuha8Yzmq', 'last_tweet_created_at': '2020-09-28 17:20:01'}
# {'screen_name': 'glifocat', 'created_at': 'Wed Mar 25 22:15:42 +0000 2015', 'last_tweet_text': '@Currofile Las mejores que hemos probado en casa a todos niveles (comodidad, durabilidad, ajuste, homologación y re… https://t.co/NbiW4PK3xI', 'last_tweet_created_at': '2020-08-31 18:57:33'}
# {'screen_name': 'RicardBorras', 'created_at': 'Mon Jan 04 20:08:23 +0000 2010', 'last_tweet_text': 'RT @Counterest: @thenextweb has recognised #Barcelona as one of the biggest #innovation hubs in Europe and Counterest is among the 200 play…', 'last_tweet_created_at': '2019-04-10 06:51:01'}
# {'screen_name': 'l41r4', 'created_at': 'Thu Dec 10 15:29:23 +0000 2009', 'last_tweet_text': '@ClaraGrima Me ha dado una ternura leerte... me he acordado de cierto melenas diminuto y su libretita de números de Fibonacci.', 'last_tweet_created_at': '2020-10-18 14:39:38'}
# {'screen_name': 'jazzyjonahj', 'created_at': 'Mon Nov 07 00:17:20 +0000 2011', 'last_tweet_text': 'Oxygen Supply Just Failed in Part of The ISS, But Everyone Is Safe So Far https://t.co/KGVzUT8XfU https://t.co/EiMpNSJZmA', 'last_tweet_created_at': '2020-10-19 15:42:02'}
# {'screen_name': 'GuillermoTbb', 'created_at': 'Tue Dec 23 16:39:27 +0000 2014', 'last_tweet_text': '@LRsecreta @doctorgaona quizá lo encontráis interesante para comentar en vuestros programas. 💭', 'last_tweet_created_at': '2020-05-31 11:20:22'}
# {'screen_name': 'AntonAubanell', 'created_at': 'Thu Jul 14 19:47:50 +0000 2011', 'last_tweet_text': '@mmart659 @alegallardo28 Gràcies Manel! Els ulls del amics sempre fan créixer el que fem! Moltes gràcies!\nRecords!!!!!!!!', 'last_tweet_created_at': '2020-10-10 11:00:34'}
# {'screen_name': 'teresaalarcos', 'created_at': 'Sat Feb 27 13:16:13 +0000 2010', 'last_tweet_text': 'RT @soydigitalwoman: ¿Quieres conocer a Marta Palacios... Y cómo llego a lanzar @IndomotivES? ▶ Ven a nuestro #StartupHolicDay el prox. 12…', 'last_tweet_created_at': '2020-10-19 17:36:48'}
# {'screen_name': 'aniues', 'created_at': 'Thu Apr 18 09:14:20 +0000 2013', 'last_tweet_text': 'RT @pacoxino: Un altre vegada amb els negocis. @bcn_ajuntament Reserva de sol. Habitatges per a les families. #HabitemLesDrassanes', 'last_tweet_created_at': '2020-10-19 15:43:37'}
# {'screen_name': 'Gemma_Ortiga', 'created_at': 'Sun Feb 28 11:23:18 +0000 2016', 'last_tweet_text': 'RT @lauragortensi: Com a "youtuber" no em guanyaré la vida, però feu el favor de llegir "Em dic Lucy Barton". Xalareu.', 'last_tweet_created_at': '2020-04-08 12:00:20'}
# {'screen_name': 'mrosa_bay', 'created_at': 'Fri Dec 09 19:42:20 +0000 2011', 'last_tweet_text': 'RT @sindics1octubre: 📢 La comunitat universitària és al costat dels #Síndics1Oabsolució i els estudiants, punta de llança de les mobilitzac…', 'last_tweet_created_at': '2020-10-19 15:23:12'}
# {'screen_name': 'AniraEscrichs', 'created_at': 'Wed Sep 20 22:58:09 +0000 2017', 'last_tweet_text': 'RT @PHDcomics: Guess what https://t.co/OTGEFHiw27', 'last_tweet_created_at': '2020-10-06 16:36:23'}
# {'screen_name': 'rosafabregues', 'created_at': 'Fri Feb 18 10:34:36 +0000 2011', 'last_tweet_text': 'RT @jcasanovas: https://t.co/wSTnKD5KAx', 'last_tweet_created_at': '2019-11-18 16:30:43'}
# {'screen_name': 'bcnscience', 'created_at': 'Mon Nov 29 21:40:23 +0000 2010', 'last_tweet_text': "RT @crai_ub: Webinar en el marc de la Setmana de l'Accés Obert 2020\n\n💻Més enllà de la publicació en accés obert: les plataformes de publica…", 'last_tweet_created_at': '2020-10-19 19:32:15'}
# {'screen_name': 'AquestFrederic', 'created_at': 'Thu May 21 15:25:25 +0000 2015', 'last_tweet_text': 'RT @VilaWeb: Dos regidors del PSC se sumen a la llista de represaliats del Primer d’Octubre: els demanen tres anys de presó https://t.co/WV…', 'last_tweet_created_at': '2020-10-19 17:04:52'}
# {'screen_name': 'epaluzie', 'created_at': 'Sun Oct 17 18:09:20 +0000 2010', 'last_tweet_text': 'RT @ClaraPonsati: Avui, al Parlament Europeu, he reclamat que la Comissió Europea deixi de tolerar que els Estats Membres abusin de la tecn…', 'last_tweet_created_at': '2020-10-19 19:05:08'}
# {'screen_name': 'CostabravaToday', 'created_at': 'Tue Oct 28 10:56:33 +0000 2008', 'last_tweet_text': 'RT @GenisPinart: #tramuntana #elportdelaselva #capdecreus #emporda #costabrava #Catalunya #catalunyaexperience #tardor #windsurfing #ElTemp…', 'last_tweet_created_at': '2020-10-14 08:07:25'}
# {'screen_name': 's3n3ts0m3d', 'created_at': 'Sat Aug 26 02:12:46 +0000 2017', 'last_tweet_text': 'RT @gabrielrufian: Españoles, os hablan de Catalunya mientras os roban la democracia.\nhttps://t.co/avV5NDKe6h', 'last_tweet_created_at': '2017-11-29 11:29:28'}
# {'screen_name': 'Jorch1122', 'created_at': 'Fri Sep 15 13:26:09 +0000 2017', 'last_tweet_text': 'Signeu aquesta important iniciativa, pel reconeixement dels Països Catalans i altres regions nacionals no reconegud… https://t.co/m1nErIn0hd', 'last_tweet_created_at': '2020-10-10 12:19:19'}
# {'screen_name': 'adriferqu', 'created_at': 'Sat Jul 23 19:30:53 +0000 2016', 'last_tweet_text': 'Lo único productivo que hice en las mesas del macià... @DavidBonillaMo6  @aalexlinares07 https://t.co/6cpX4gMC35', 'last_tweet_created_at': '2019-01-15 23:33:56'}
# {'screen_name': 'jcabasesvega', 'created_at': 'Thu Oct 27 22:02:04 +0000 2011', 'last_tweet_text': 'RT @jcabasesvega: Desmantelada en Beirut una red de trabajadores del aeropuerto que enviaba ilegalmente personas a #España.\n\nEn @eldiarioes…', 'last_tweet_created_at': '2020-10-19 18:44:55'}
# {'screen_name': 'XavierRoige', 'created_at': 'Wed Aug 04 22:39:00 +0000 2010', 'last_tweet_text': 'RT @jordisopena: 👉 El @MIT, pionero en potenciar los perfiles híbridos del profesorado universitario #tecnología #innovación  https://t.co/…', 'last_tweet_created_at': '2020-10-19 13:39:25'}
# {'screen_name': 'AnnaPpena', 'created_at': 'Mon Jan 09 13:15:16 +0000 2017', 'last_tweet_text': 'RT @Llunagroga: @FenixNegre Avui a les 19h Hi anirà gent amb el llaç groc. Aviam si es poden gravar les amenaces i els insults.', 'last_tweet_created_at': '2017-12-20 17:13:27'}
# {'screen_name': 'assemblea', 'created_at': 'Tue Feb 22 14:12:53 +0000 2011', 'last_tweet_text': '⬛️⬜️ Enhorabona al poble de Bolívia, que ha revertit a les urnes i de manera democràtica, clara i valenta, el cop d… https://t.co/WXr1vihjRz', 'last_tweet_created_at': '2020-10-19 17:54:24'}
# {'screen_name': 'oriolrg', 'created_at': 'Mon May 24 21:37:15 +0000 2010', 'last_tweet_text': "Les restriccions, les lleis, les normatives i un llarg etcètera... Tot s'adapta a la metròpoli, deixant de banda el… https://t.co/zjSpYCOcIx", 'last_tweet_created_at': '2020-10-15 21:17:25'}
# {'screen_name': 'rballeba', 'created_at': 'Fri Mar 18 19:32:41 +0000 2016', 'last_tweet_text': '@arnaugamez I have skimmed your thesis. Congratulations! It seems very worth reading so I will do it!', 'last_tweet_created_at': '2020-08-25 16:37:44'}
# {'screen_name': 'angel_efta', 'created_at': 'Thu Feb 23 16:15:51 +0000 2012', 'last_tweet_text': 'RT @boye_g: Tus jueces por mis jueces vía @elnacionalcat_e https://t.co/ksi9Tmnr6K', 'last_tweet_created_at': '2020-10-16 05:16:30'}
# {'screen_name': 'lousmontabes', 'created_at': 'Tue Jul 23 02:03:03 +0000 2013', 'last_tweet_text': '@montabes_ Vente con los montabes barceloneses!', 'last_tweet_created_at': '2020-10-18 14:22:30'}
# ...
# {'screen_name': 'al_solanes', 'created_at': 'Fri Nov 23 09:37:14 +0000 2012', 'last_tweet_text': '@elmundoes Aprendan a leer. Piden que no sea la primera medida, no que no se tenga que hacer.', 'last_tweet_created_at': '2020-10-14 05:28:16'}
# {'screen_name': 'CalellaRockFest', 'created_at': 'Sun Jan 13 19:52:53 +0000 2013', 'last_tweet_text': 'RT @DrakonsIO: Pyro Drakons Unleashed! \n\nGrab them now. Look for perfect ASI. 38-33-53!\nhttps://t.co/NbivfFYyVC\n\n#BeADrakonMaster https://t…', 'last_tweet_created_at': '2020-03-10 19:50:22'}
# {'screen_name': 'BibmatUB', 'created_at': 'Tue Apr 16 09:03:28 +0000 2013', 'last_tweet_text': "RT @crai_ub: 🔓 Setmana de l'Accés Obert 2020 al #CRAIUB 🔓\n\nConsulteu les activitats programades! 🔗 https://t.co/7346081nj5\n\n#OAweek #OpenAc…", 'last_tweet_created_at': '2020-10-19 14:34:04'}
# {'screen_name': 'oriMatematiques', 'created_at': 'Fri Apr 25 09:42:47 +0000 2014', 'last_tweet_text': 'Oberta convocatòria per cursar estudis diplomàtics\n\nhttp://t.co/0ilz7YisTW', 'last_tweet_created_at': '2015-06-22 10:57:43'}
# {'screen_name': 'Nigsia', 'created_at': 'Sat Oct 08 11:44:49 +0000 2011', 'last_tweet_text': '@CrossingLux @Aliarachan @EvilAFM Quizás con @ChioUyuni tenemos más suerte ^^', 'last_tweet_created_at': '2020-10-18 10:22:38'}
# {'screen_name': 'BarberoDormilon', 'created_at': 'Sun Nov 04 17:14:12 +0000 2012', 'last_tweet_text': '@DellSpain #dellnosengaña confié en Dell y me timo. Sigo esperando mi portátil.', 'last_tweet_created_at': '2019-06-19 21:04:27'}
# {'screen_name': 'crazykram28', 'created_at': 'Thu Dec 08 13:51:09 +0000 2011', 'last_tweet_text': 'RT @pablom_m: En Brasil, una niña de 10 años fue violada desde los 6 por uno de sus tíos. Se quedó embarazada y un juez autorizó el aborto.…', 'last_tweet_created_at': '2020-08-19 10:11:20'}
# {'screen_name': 'daperezpa', 'created_at': 'Tue Jan 21 13:55:06 +0000 2014', 'last_tweet_text': 'RT @albertcorbi: No te lo piertas! Modelos matemáticos para epidemias: de la teoría a la realidad.\n- Día 22 de abril a las 19h\n- Inscríbete…', 'last_tweet_created_at': '2020-04-17 15:52:20'}
# {'screen_name': 'gvigosch', 'created_at': 'Wed Sep 29 11:56:58 +0000 2010', 'last_tweet_text': '@issux @twyp_es Pudiste resolverlo?', 'last_tweet_created_at': '2020-04-11 09:38:08'}
# {'screen_name': 'pablomm6', 'created_at': 'Mon Feb 07 23:35:20 +0000 2011', 'last_tweet_text': 'RT @alvaromzt: https://t.co/NR5LJXoO0b', 'last_tweet_created_at': '2020-10-07 06:59:46'}
# {'screen_name': 'xaviml93', 'created_at': 'Tue Oct 16 10:25:49 +0000 2012', 'last_tweet_text': 'RT @pkober: Why Prop 13 is terrible policy in two photos. One homeowner pays $500/year in property taxes. Their next door neighbor pays ove…', 'last_tweet_created_at': '2020-10-14 19:44:55'}
# {'screen_name': 'David_Software', 'created_at': 'Wed Feb 26 15:55:50 +0000 2014', 'last_tweet_text': 'Xubuntu Focal Fossa (20.04) Minimal VirtualBox. Enjoy!\nhttps://t.co/alvdtKEhxz', 'last_tweet_created_at': '2020-05-10 13:43:18'}
# {'screen_name': 'adri_romsor', 'created_at': 'Thu Feb 20 10:36:03 +0000 2014', 'last_tweet_text': 'RT @caglarml: Our post-workshop report on science meets engineering in deep learning #NeurIPS 2019 is on arXiv now: https://t.co/NE5YzCoEd1…', 'last_tweet_created_at': '2020-10-06 11:12:17'}
# {'screen_name': 'dtantos_uno', 'created_at': 'Wed Feb 19 11:50:56 +0000 2014', 'last_tweet_text': 'RT @AVallcarca: #ElBancResisteix https://t.co/PIAayaTOHN', 'last_tweet_created_at': '2016-05-23 08:36:38'}
# {'screen_name': 'polo070770', 'created_at': 'Fri Feb 14 12:49:25 +0000 2014', 'last_tweet_text': 'RT @UnSrdeBarcelona: 1 de Mayo, 2018\n\nJeff Bezos,dueño de Amazon y hombre más rico del mundo, recibe en su móvil un whatsapp del Príncipe h…', 'last_tweet_created_at': '2020-01-26 07:37:15'}
# {'screen_name': 'marinmenyo', 'created_at': 'Wed Jan 27 18:32:58 +0000 2010', 'last_tweet_text': '@Luis_pastor Facultat de Filosofia, Geografia i Història. Universitat de Barcelona. (1976-2006) https://t.co/foYSqMcGG3', 'last_tweet_created_at': '2020-10-16 07:13:18'}
# {'screen_name': 'tian1992_orq', 'created_at': 'Fri Feb 14 23:29:23 +0000 2014', 'last_tweet_text': "I'm playing WordBrain and I've just reached brain size 12! #WordBrain  #wordshhhgf@#vfgk@#@@#####hjjbjjk@klmm#m#lbnnjnkmmmppppllpkm", 'last_tweet_created_at': '2016-10-29 06:40:06'}
# {'screen_name': 'PussInBootsGB', 'created_at': 'Wed Jan 01 20:45:14 +0000 2014', 'last_tweet_text': '@elmonarac1 no em crec el que estic escoltant. #Masclisme lamentable. Les dones ho tenen més fàcil que els homes a la política? De debò?', 'last_tweet_created_at': '2016-04-28 07:20:30'}
# {'screen_name': 'alexroyar', 'created_at': 'Sun Feb 06 23:32:30 +0000 2011', 'last_tweet_text': 'RT @thecodinglove: When I try to implement multithreading https://t.co/Lson55nsm4 #thecodinglove https://t.co/v6XI4ZRPjJ', 'last_tweet_created_at': '2020-10-08 17:14:00'}
# {'screen_name': 'anna_casas', 'created_at': 'Tue Mar 02 14:14:20 +0000 2010', 'last_tweet_text': '@SEUR_responde me encanta llamaros y que me digáis que no me podéis atender, que hable con la máquina que no me da… https://t.co/3fbcCOSw7y', 'last_tweet_created_at': '2020-10-16 13:59:48'}
# {'screen_name': 'Ruchmaister', 'created_at': 'Thu Jul 18 07:20:07 +0000 2013', 'last_tweet_text': 'RT @Albertocandome: Si hoy gana @FNATIC doy 100€ a cada Rt #Worlds2020 https://t.co/bE7KOX6KAO', 'last_tweet_created_at': '2020-10-17 14:28:01'}
# {'screen_name': 'jvsanchez28', 'created_at': 'Sun Jun 10 12:15:54 +0000 2012', 'last_tweet_text': 'https://t.co/hpEmVqq0a7', 'last_tweet_created_at': '2020-07-10 12:04:50'}
# {'screen_name': 'serxi_88', 'created_at': 'Wed Nov 26 15:11:35 +0000 2008', 'last_tweet_text': 'Samsung Galaxy S8 International Giveaway! https://t.co/Q82Nnqzaz5', 'last_tweet_created_at': '2017-04-30 17:25:00'}
# {'screen_name': 'berenguel', 'created_at': 'Fri Nov 21 11:12:31 +0000 2008', 'last_tweet_text': '@sevave @xibi_xibi Sembla que es va fer segons el tweet, però ja demanar-ho és una mica... jo no ho faria a Anglate… https://t.co/Ul69XXBhK2', 'last_tweet_created_at': '2020-10-19 14:38:04'}
# {'screen_name': 'drfarres', 'created_at': 'Tue Sep 14 21:42:28 +0000 2010', 'last_tweet_text': '@MasVillaverde Pq sino se quedan en el bar todo el dia y la famila esta a salvo! Claro? Logica Aplastante! 🤦🏼\u200d♀️🤦🏼\u200d♀️', 'last_tweet_created_at': '2020-10-14 14:28:07'}
# {'screen_name': 'pepe_aponte', 'created_at': 'Fri Jan 07 10:01:27 +0000 2011', 'last_tweet_text': 'J https://t.co/PM0QDxYiMO', 'last_tweet_created_at': '2018-07-31 09:36:30'}
# {'screen_name': 'oriolpujolvila', 'created_at': 'Mon Dec 02 14:54:08 +0000 2013', 'last_tweet_text': "RT @ProfFeynman: If you're the smartest person in the room, then you're in the wrong room. 🧠", 'last_tweet_created_at': '2020-10-19 10:36:46'}
# {'screen_name': 'poncevi', 'created_at': 'Sat Mar 19 21:29:37 +0000 2011', 'last_tweet_text': 'https://t.co/nUExWiUDOT', 'last_tweet_created_at': '2020-07-23 13:42:04'}
# {'screen_name': 'Edinbros', 'created_at': 'Mon Jul 29 09:48:41 +0000 2013', 'last_tweet_text': 'Air Hockey Madness update! Play now for free! -&gt; http://t.co/3W5kPaYeaC #android #google #play #googleplay #game #hockey #airhockey #free', 'last_tweet_created_at': '2014-02-15 02:59:12'}
# {'screen_name': 'vce87', 'created_at': 'Wed Nov 04 22:22:21 +0000 2009', 'last_tweet_text': '@angelmartin_nc Estamos ansiosos', 'last_tweet_created_at': '2020-10-16 04:38:11'}
# {'screen_name': 'jacintkure', 'created_at': 'Sun Feb 13 22:54:08 +0000 2011', 'last_tweet_text': '@Marimar96295361 @dracdolot @sanchezcastejon https://t.co/Ta1yqvEAYs', 'last_tweet_created_at': '2020-09-11 10:13:05'}
# {'screen_name': 'superfastgoat96', 'created_at': 'Thu Apr 05 20:13:09 +0000 2012', 'last_tweet_text': '@sergioch23 @FlutterDev llego demasiado tarde, a la próxima', 'last_tweet_created_at': '2020-10-11 22:34:45'}
# {'screen_name': 'Lynos_Sorien', 'created_at': 'Fri May 27 16:29:35 +0000 2011', 'last_tweet_text': 'RT @aupafigura: https://t.co/PdnIZXzk5j', 'last_tweet_created_at': '2020-10-14 06:19:03'}
# {'screen_name': 'Neoares92', 'created_at': 'Sat Jul 16 11:03:09 +0000 2011', 'last_tweet_text': '@Risem27 @AlterTimeSK que te puedes cortar el pito', 'last_tweet_created_at': '2020-10-14 15:46:28'}
# {'screen_name': 'sergiala', 'created_at': 'Sun Sep 18 15:14:38 +0000 2011', 'last_tweet_text': '@Joan_Martinez90 @mironet20 @WoWCatalunya @Llumifoscor @Gaming_catala https://t.co/YP03rj84Ly', 'last_tweet_created_at': '2020-08-18 08:12:33'}
# {'screen_name': 'MarcAllende3', 'created_at': 'Wed Sep 12 14:33:34 +0000 2012', 'last_tweet_text': 'Yo me haria una selfie en Montserrat #WortenEstrena #iPhoneYMINI', 'last_tweet_created_at': '2016-12-19 17:54:36'}
# {'screen_name': 'moralespetit', 'created_at': 'Thu Sep 15 19:47:18 +0000 2011', 'last_tweet_text': '@emfandirRoger Simplement, puta merda!', 'last_tweet_created_at': '2020-10-19 19:08:26'}
# {'screen_name': 'roctovar', 'created_at': 'Sat Feb 16 09:10:20 +0000 2013', 'last_tweet_text': "RT @gatesfoundation: Don't have a red nose? That's ok! For every RT we'll donate $10 toward ending child poverty. #RedNose4Kids https://t.c…", 'last_tweet_created_at': '2016-05-22 09:30:13'}
# {'screen_name': 'osc_car', 'created_at': 'Sat May 29 23:31:23 +0000 2010', 'last_tweet_text': 'RT @mariocantos: Quiero que veáis esto. Simplemente tiene que verse la cara del individuo gritando como un mono. \nNo podemos permitir esto.…', 'last_tweet_created_at': '2020-05-23 19:13:37'}
# {'screen_name': 'Hiro_cat', 'created_at': 'Thu Apr 03 22:44:08 +0000 2008', 'last_tweet_text': 'RT @Houseof_CAT: Creen que si acaban con Puigdemont el independentismo se evaporará, pensaron lo mismo con Mas, queda claro que la intelige…', 'last_tweet_created_at': '2018-03-25 21:42:28'}
# {'screen_name': 'davidcorto', 'created_at': 'Tue Jun 22 10:50:25 +0000 2010', 'last_tweet_text': 'RT @FacesPics: A concretesaurus eating rebars https://t.co/BQUn2LCLfI', 'last_tweet_created_at': '2020-10-17 07:25:04'}
# {'screen_name': 'espavilat', 'created_at': 'Mon Nov 22 14:27:10 +0000 2010', 'last_tweet_text': '@fxn Check out this Meetup with Full Stack Vallès https://t.co/gH4RmktrOj #vallesencs no us ho podeu perdre!!!', 'last_tweet_created_at': '2019-02-04 19:02:52'}
# {'screen_name': 'Laura_Igual', 'created_at': 'Mon Nov 05 16:52:05 +0000 2012', 'last_tweet_text': '@gloriatrullas @mireialite @vendedoradprosa @Malcolm_9 @meigul @cfuenteslaroche @lunamonelle @pilarreyesf… https://t.co/lfQSZVtb3B', 'last_tweet_created_at': '2020-05-03 08:02:36'}
# {'screen_name': '_marcmf', 'created_at': 'Tue Jul 31 12:27:48 +0000 2012', 'last_tweet_text': '@rumireports This is a pen! https://t.co/Rkqot1qk7R', 'last_tweet_created_at': '2020-05-21 11:22:21'}
# {'screen_name': 'SolansDavid', 'created_at': 'Mon May 21 21:33:37 +0000 2012', 'last_tweet_text': 'RT @ECMLPKDD: The Test of Time award is given annually for a paper with a lasting impact in our field. For the visionary work in their 2010…', 'last_tweet_created_at': '2020-09-16 09:24:58'}
# {'screen_name': 'Davidnp10', 'created_at': 'Fri Feb 24 00:42:10 +0000 2012', 'last_tweet_text': 'RT @hollenbachgurl: me when the Spanish professor asks the class how to say tree https://t.co/Txoy1iRAKi', 'last_tweet_created_at': '2020-08-24 12:49:21'}
# {'screen_name': 'Jordi_Canela', 'created_at': 'Mon Mar 05 11:34:12 +0000 2012', 'last_tweet_text': 'RT @pnaltpirineu: Es presenta a #MonNaturaPirineus la primera cria de #gatillop (#Lynxlynx) nascuda als Pirineus des de fa un segle. Espèci…', 'last_tweet_created_at': '2019-08-07 22:34:08'}
# {'screen_name': 'juancarlos_cat', 'created_at': 'Wed Feb 08 17:16:35 +0000 2012', 'last_tweet_text': '@yaizalloriginal @Nachsoyyo Hambriento es una gran muestra de su talento para la escritura. Extenso contenido que c… https://t.co/ryLitpwBAh', 'last_tweet_created_at': '2019-01-16 10:19:57'}
# {'screen_name': 'MalcomAkbar', 'created_at': 'Thu Feb 16 10:49:18 +0000 2012', 'last_tweet_text': '#CaraACaraL6', 'last_tweet_created_at': '2015-12-14 22:21:03'}
# {'screen_name': 'Alcazso', 'created_at': 'Sun Dec 04 13:11:33 +0000 2011', 'last_tweet_text': "@324cat Sou pesats eh! D'on treieu aquestes dades? A dit? O es tracta només de fotre por a la població, com va la estratègia?", 'last_tweet_created_at': '2020-09-04 13:12:05'}
# {'screen_name': '_ira3w', 'created_at': 'Thu Feb 16 05:21:21 +0000 2012', 'last_tweet_text': 'RT @Portaventura_ES: #SORTEO ¿Quieres ganar una entrada doble para Caribe Aquatic Park y hacer splash este verano en nuestro parque acuátic…', 'last_tweet_created_at': '2019-05-30 21:54:08'}
# {'screen_name': 'dlopezhi7', 'created_at': 'Thu Mar 03 15:38:05 +0000 2011', 'last_tweet_text': "RT @lopez_2007: Hola @CafesNovell a l'hospital d'igualada, a les valentes que están a la planta sociosanitaria els hi vindria molt bé una c…", 'last_tweet_created_at': '2020-03-29 11:12:18'}
# {'screen_name': 'MarkBS1991', 'created_at': 'Sun May 16 11:15:24 +0000 2010', 'last_tweet_text': 'RT @YolandaDeMena: Mi novio anoche se despertó a las 4am diciendo q habia soñado con un nuevo papa llamado "Francisco I" y hoy benedicto ...', 'last_tweet_created_at': '2013-03-14 15:32:16'}
# {'screen_name': 'svartahajen', 'created_at': 'Wed Feb 15 09:17:47 +0000 2012', 'last_tweet_text': '@CAC_Fnac_ESP Hola! He comprado un pedido de una edición limitada de la que ya no había stock y pone el en estado “… https://t.co/lP13nAywjk', 'last_tweet_created_at': '2019-12-27 12:02:30'}
# {'screen_name': 'alex_pardo5', 'created_at': 'Mon Jul 12 21:46:33 +0000 2010', 'last_tweet_text': 'RT @osaumell: Tots dos són mestres. El referent de Covid de l’escola del pare li diu que no, i el referent de l’escola de la mare li diu qu…', 'last_tweet_created_at': '2020-10-18 19:25:23'}
# {'screen_name': 'AprendeCosasAC', 'created_at': 'Thu Dec 22 23:02:24 +0000 2011', 'last_tweet_text': '@eloipuertas ¿Nuestra entrega es correcta? somos Pablo y Alexandre. El código esta dentro del .war en WEB-INF en la carpeta src', 'last_tweet_created_at': '2012-06-05 18:13:49'}
# {'screen_name': 'vitbcn', 'created_at': 'Mon Feb 08 21:49:11 +0000 2010', 'last_tweet_text': '@AthalberthH por?', 'last_tweet_created_at': '2013-06-13 12:21:45'}
# {'screen_name': 'vnovor', 'created_at': 'Sat Feb 11 21:41:57 +0000 2012', 'last_tweet_text': 'Adios Unity, Hola Mate, esto ya se ve como me gusta', 'last_tweet_created_at': '2012-02-13 10:44:15'}
# {'screen_name': 'Alvykun', 'created_at': 'Sun Feb 12 02:39:33 +0000 2012', 'last_tweet_text': 'RT @roma_gallardo: Sociedad enferma. Cobardía, analfabetismo, y sadismo, todo en un solo gesto. https://t.co/dLjJTTz1ZM', 'last_tweet_created_at': '2020-07-31 00:21:00'}
# {'screen_name': 'jacsparragow', 'created_at': 'Thu Mar 24 18:59:31 +0000 2011', 'last_tweet_text': 'RT @Digital_Legends: It was awesome to have the inventor of FPS @romero visiting and playing our shooters. Thks for coming! https://t.co/2x…', 'last_tweet_created_at': '2016-07-06 19:39:01'}
# {'screen_name': 'emanzanomarcos', 'created_at': 'Tue Mar 09 19:47:11 +0000 2010', 'last_tweet_text': '@NerBlack Eres LaRusso dojo o Cobra Kai com déu mana?', 'last_tweet_created_at': '2020-10-11 17:57:52'}
# {'screen_name': '_guilleruiz', 'created_at': 'Wed Jan 19 10:16:44 +0000 2011', 'last_tweet_text': 'great work from @Gil_Triginer et al.', 'last_tweet_created_at': '2020-09-22 13:32:48'}
# {'screen_name': 'sergi711', 'created_at': 'Mon Aug 30 17:18:11 +0000 2010', 'last_tweet_text': '@lmartinr70 @84Manresa @Wargo25 @MGranizoV @MaximumBCN Grandes !!', 'last_tweet_created_at': '2019-07-12 16:44:48'}
# {'screen_name': 'isaFresquibiris', 'created_at': 'Mon Sep 19 10:23:52 +0000 2011', 'last_tweet_text': 'RT @mmarinuss: no se quien es la autora, pero lo dejo por aquí y me voy https://t.co/enTwaL3t6y', 'last_tweet_created_at': '2020-09-23 16:56:50'}

# %% [markdown]
# 2- **Selenium EXERCISE:**
# <ul>
# <li> Open a browser
#
# <li>Go to tripadvisor/Restaurants
#
# <li>Find the search text box
#
# <li>Clear it, input the query "Sant Cugat" and send it
#
# <li>Go to "Restarurants" and get the name and link of the top 10 restaurants in Sant cugat
# <li> Store them into a database called 'TripAdvisor' and a collection called 'Restaurants' with the documents atributes 'name' and 'link'
# </ul>
#
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
import pymongo

# Create the db
conn = pymongo.MongoClient()
db = conn['TripAdvisor']
collection = db.Restaurants

# CHANGE THE PATH WHEN YOU CORRECT IT
driver = webdriver.Chrome("chromedriver")
#---------------------------------------------------------------------------
driver.get('https://www.tripadvisor.es/Restaurants')

# find the search text box and write and look for Sant Cugat restaurants
text_box = driver.find_element_by_xpath('//*[@id="component_6"]/div/div/form/input[1]')
text_box.click()
text_box.send_keys('Sant Cugat del Vallès')
time.sleep(5)
driver.find_element_by_css_selector("a[href*='Sant_Cugat']").click()

# get top 10 restaurant
results = driver.find_element_by_xpath('//*[@id="component_2"]/div')
items = results.find_elements_by_css_selector('a[href*=REVIEWS]')
items2 = results.find_elements_by_class_name('wQjYiB7z')

names = []
links= []

for item, item2 in zip(items,items2):
    s = item2.get_attribute('innerHTML')
    restaurant_name = re.search("<!-- -->. <!-- -->(.*?)</a></span>", s)
    # filter promoted ones (Return None on search of pattern)
    if restaurant_name != None:
        names.append(restaurant_name.group(1))
        links.append(item.get_attribute('href').strip('#REVIEWS'))
        

names = names[:10]  
links = links[:10]

for name, link in zip(names, links):
    collection.insert_one({"restaurant": name, "link": link})

# %%
for x in collection.find({}, {"_id":0, "restaurant": 1, "link": 1}):  
    print(x)
# Out:
# {'restaurant': 'Piaceri D’ Italia Ristorante Pizzeria', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d19084243-Reviews-Piaceri_D_Italia_Ristorante_Pizzeria-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'Restaurant Brau', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d10195584-Reviews-Restaurant_Brau-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'La Rita', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d10365477-Reviews-La_Rita-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'Sabàtic', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d10167691-Reviews-Sabatic-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'Némesis Gastronomia', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d11892809-Reviews-Nemesis_Gastronomia-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'El vi de deu', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d7076969-Reviews-El_Vi_de_Deu-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'Dakidaya', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d4546707-Reviews-Dakidaya-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'bodega tomas', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d7912636-Reviews-Bodega_Tomas-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'La Rampa 23', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d4043880-Reviews-La_Rampa_23-Sant_Cugat_del_Valles_Catalonia.html'}
# {'restaurant': 'Kitsune Sushi Bar', 'link': 'https://www.tripadvisor.es/Restaurant_Review-g1080422-d5966644-Reviews-Kitsune_Sushi_Bar-Sant_Cugat_del_Valles_Catalonia.html'}
