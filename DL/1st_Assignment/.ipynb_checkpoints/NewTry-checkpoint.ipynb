# %% [markdown]
# # 1st Assignment: NN's from Scratch
#
# The objective is to build from scratch a neural network to perform  classification. Let's firt consider the follwing 2-class dataset:

# %%
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib
import autograd.numpy as np
from autograd import grad
from autograd.misc import flatten

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

# Generate a dataset and plot it
np.random.seed(0)
X, y = sklearn.datasets.make_moons(1000, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, alpha=0.45)

# %% [markdown]
# We will use a **3-layer classification neural network** with one input layer, one hidden layer, and one output layer.
#
# The number of nodes in the input layer will be determined by the dimensionality of our data (2). Similarly, the number of nodes in the output layer is determined by the number of classes $C$ we have (also 2).
#
# Our network makes predictions using forward propagation, which is just a bunch of matrix multiplications and the application of the activation function $\sigma$.
#
# If $x$ is the input to our network then we calculate our prediction $\hat{y}$ as follows:
#
# $$ z_1 = x W_1 + b_1 $$
# $$ a_1 = \sigma(z_1) $$
# $$ z_2 = a_1 W_2 + b_2$$
# $$ y = \mbox{softmax}({z_2})$$
#
# where $y$ is a multidimensional vector representing a probability distribution over classes, $\sigma$ is a non linear function and $W_1, b_1, W_2, b_2$ are parameters of our network, which we need to learn from our training data. You can think of the parameters $W$ as matrices transforming data between layers of the network.
#
# Looking at the matrix multiplications above we can figure out the dimensionality of these matrices in our problem. If we use 500 nodes for our hidden layer then $W_1 \in \mathbb{R}^{2\times500}$, $b_1 \in \mathbb{R}^{500}$, $W_2 \in \mathbb{R}^{500\times2}$, $b_2 \in \mathbb{R}^{2}$.
#
# The last layer is a `softmax` function. The softmax function is a generalization of the logistic function to multiple dimensions. It is used to normalize the output of a network to a probability distribution over predicted output classes.
#
# The softmax function takes as input a vector $C$ of real numbers, and normalizes it into a probability distribution consisting of $C$ probabilities proportional to the exponentials of the input numbers:
#
# $$softmax(z_i) = \frac{exp(z_i)}{\sum_{j=1}^{C}exp(z_j))}$$
#
# A common choice with the softmax output is the **cross-entropy loss**. If we have $N$ training examples in our minibatch dataset and $C$ classes, then the loss for our prediction $\hat{y}$ for that minibatch with respect to the true labels $y$ is given by:
#
# $$
# \begin{aligned}
# L(y,\hat{y}) = - \frac{1}{N} \sum_{n \in N} \sum_{i \in C} y_{n,i} \log\hat{y}_{n,i}
# \end{aligned}
# $$

# %% [markdown]
# Let's now define some general parameters:

# %%
num_examples = len(X) # training set size
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
sigma = np.tanh # activation function

# Gradient descent parameters 
epsilon = 0.01 # learning rate for gradient descent
reg_lambda = 0.01 # regularization strength

# %%
# loss function for a 3-layer MLP
def loss(model):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation to calculate our predictions
    z1 = np.dot(X,W1) + b1
    a1 = sigma(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
    return 1./num_examples * data_loss

# forward propagation
def predict(model, x):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    z1 = np.dot(x,W1) + b1
    a1 = sigma(z1)
    z2 = np.dot(a1,W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations

def build_model(nn_hdim, num_passes=50000, print_loss=False):
    
    # Initialize the parameters to random values. 
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        predict(model, X)

        # computing the derivative by AD        
        gradient_loss = grad(loss)

        # flattening nested containers containing numpy arrays
        # Returns 1D numpy array and an unflatten function.
        model_flat, unflatten_m = flatten(model)
        grad_flat, unflatten_g = flatten(gradient_loss(model))
        
        # gradient descend
        model_flat -= grad_flat * epsilon
        model = unflatten_m(model_flat)

        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
            print("Loss after iteration %i: %f" %(i, loss(model)))
    
    return model

# Build a model with a 3-dimensional hidden layer
model = build_model(3, print_loss=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-0057b5405adb> in <module>
#      42
#      43 # Build a model with a 3-dimensional hidden layer
# ---> 44 model = build_model(3, print_loss=True)
#
# <ipython-input-103-0057b5405adb> in build_model(nn_hdim, num_passes, print_loss)
#       8     # Initialize the parameters to random values.
#       9     np.random.seed(0)
# ---> 10     W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
#      11     b1 = np.zeros((1, nn_hdim))
#      12     W2 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
#
# NameError: name 'nn_input_dim' is not defined

# %%
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, alpha=0.45)
    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.45)

    
# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model, x))
plt.title("Decision Boundary for hidden layer size 3")

# %% [markdown]
# # Exercise 1
#
# Add an additional layer to your neural network model. Change the activation function and use a ReLU. Does it work?

# %%
# your code here

# %% [markdown]
# # Exercise 2
#
# Design (change parameters) and train a NN to classify the following dataset.

# %%
import autograd.numpy as np
import matplotlib.pyplot as plt

def twospirals(n_points, noise=.5):
    """
     Returns the two spirals dataset.
    """
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(n_points),np.ones(n_points))))

X, y = twospirals(1000)

plt.title('training set')
plt.plot(X[y==0,0], X[y==0,1], '.', label='class 1')
plt.plot(X[y==1,0], X[y==1,1], '.', label='class 2')
plt.legend()
plt.show()

# %%
W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
b1 = np.zeros((1, nn_hdim))

W2 = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
b2 = np.zeros((1, nn_hdim)) 

W3 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
b3 = np.zeros((1, nn_output_dim))

# %%
nn_hdim = 3
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
k = 3
dic ={}
for i in range(k):
    if i == 0:
        dic['W1'] = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
        dic['b1'] = np.zeros((1, nn_hdim))
    elif i == k-1:
        dic['W'+str(k)] = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
        dic['b'+str(k)] = np.zeros((1, nn_output_dim))
    else:        
        dic['W'+str(i+1)] = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
        dic['b'+str(i+1)] = np.zeros((1, nn_hdim))
# Out:
# A 1
# C 2
# 3
# B 3

# %%
dic['W2'].shape
# Out:
# (3, 3)

# %%
W1, b1, W2, b2,W3,b3 = dic['W1'], dic['b1'], dic['W2'], dic['b2'], dic['W3'], dic['b3']

# %%
(2, 4) (4, 4) (4, 2)

# %%
print(W1.shape)
# Out:
# (2, 3)

# %%
print(W2.shape)
# Out:
# (3, 3)

# %%
print(W3.shape)
# Out:
# (3, 2)

# %%
dic
# Out:
# {'W1': array([[-1.18511366,  0.81482146,  0.76340563],
#         [-0.57513538, -1.03691859,  0.36844851]]),
#  'b1': array([[0., 0., 0.]]),
#  'W2': array([[-0.33243134,  0.0819567 , -0.18436435],
#         [ 0.39926008,  0.40111361, -0.41892384],
#         [-0.79868555, -0.91390991,  0.3524027 ]]),
#  'b2': array([[0., 0., 0.]]),
#  'W3': array([[-0.68638821, -0.29261056],
#         [-0.34428207, -0.03034974],
#         [-1.11791167,  0.10899137]]),
#  'b3': array([[0., 0.]])}

# %%
np.sum(np.square(dic['W1'])) + np.sum(np.square(dic['W2'])) + np.sum(np.square(dic['W3']))
# Out:
# 8.375091527728353

# %%
a = np.square(dic['W1'])

# %%
b = np.square(dic['W2'])

# %%
c = np.square(dic['W3'])

# %%
np.sum(a+b+c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-8b5ec127c544> in <module>
# ----> 1 np.sum(a+b+c)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,3)

# %%
suma = 0
for key in dic.keys():
    if key.startswith('W'):
        suma += np.sum(np.square(dic[key]))

# %%
suma
# Out:
# 9.429018678092866

# %%
z = np.dot(X,dic['W1']) + dic['b1']
a = (z1)
i =  1
while i >=k:
    
    z = np.dot(a,dic['W'+str(i)]) + dic['b'+str(i)]
    if i == k:
        doCross(z)
        break
    a = activFunLayer(z)
    i += 1

# %%
z1 = np.dot(X,W1) + b1
a1 = activFunLayer1(z1)


z2 = np.dot(a1,W2) + b2
a2 = activFunLayer2(z2)

z3 = np.dot(a2,W3) + b3

exp_scores = np.exp(z3)

# %%
def NN(X,y,numLayers,numNodes,activFunLayer,num_passes,epsilon,reg_lambda,print_loss):

    # loss function for a 3-layer MLP
    def loss(model, activFunLayer):
        # Forward propagation to calculate our predictions
        z = np.dot(X,model['W1']) + model['b1']
        a = activFunLayer(z)
        i =  2
        while i >=k:
            z = np.dot(a,dic['W'+str(i)]) + dic['b'+str(i)]
            if i == k:
                return cross_entropy_loss(z,model)
            a = activFunLayer(z)
            i += 1
        
    def cross_entropy_loss(z,model)
        exp_scores = np.exp(z)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        # Calculating the loss
        
        corect_logprobs = -np.log(probs[range(num_examples), y])
        
        data_loss = np.sum(corect_logprobs)
        # Add regulatization term to loss (optional)
        suma = 0
        for key in dic.keys():
            if key.startswith('W'):
                suma += np.sum(np.square(dic[key]))
        data_loss += reg_lambda * (suma)
        return 1./num_examples * data_loss
    
    # forward propagation
    def predict(model, x,activFunLayer):
        
        z = np.dot(x,model['W1']) + model['b1']
        a = activFunLayer(z)
        i =  2
        while i >=k:
            z = np.dot(a,dic['W'+str(i)]) + dic['b'+str(i)]
            if i == k:
                break
            a = activFunLayer(z)
            i += 1
            
        exp_scores = np.exp(z)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        return np.argmax(probs, axis=1)
    
    
    def build_model(numLayer,nn_hdim, activFunLayer1,activFunLayer2, num_passes, print_loss):
    
        # Initialize the parameters to random values. 
        np.random.seed(0)
        for i in range(numLayer):
            if i == 0:
                model['W1'] = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
                model['b1'] = np.zeros((1, nn_hdim))
            elif i == k-1:
                model['W'+str(numLayer)] = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
                model['b'+str(numLayer)] = np.zeros((1, nn_output_dim))
            else:        
                model['W'+str(i+1)] = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
                model['b'+str(i+1)] = np.zeros((1, nn_hdim)) 

        # Gradient descent. For each batch...
        for i in range(0, num_passes):

            # Forward propagation
            #predict(model, X,activFunLayer1,activFunLayer2)

            # computing the derivative by AD        
            gradient_loss = grad(loss)

            # flattening nested containers containing numpy arrays
            # Returns 1D numpy array and an unflatten function.
            model_flat, unflatten_m = flatten(model)
            grad_flat, unflatten_g = flatten(gradient_loss(model,activFunLayer1,activFunLayer2))

            # gradient descend
            model_flat -= grad_flat * epsilon
            model = unflatten_m(model_flat)

            # Optionally print the loss.
            # This is expensive because it uses the whole dataset, so we don't want to do it too often.
            if print_loss and i % 1000 == 0:
                print("Loss after iteration %i: %f" %(i, loss(model,activFunLayer1,activFunLayer2)))

        return model
    
    def plot_decision_boundary(pred_func,numNodes):
        # Set min and max values and give it some padding
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)
        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, alpha=0.45)
        plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.45)
        # Plot the decision boundary
        plt.title("Decision Boundary for hidden layer size "+str(numNodes))
        
    
    
    num_examples = len(X) # training set size
    nn_input_dim = 2 # input layer dimensionality
    nn_output_dim = 2 # output layer dimensionality
    
    model = build_model(numLayer,numNodes,activFunLayer1,activFunLayer2,num_passes,print_loss)
    plot_decision_boundary(lambda x: predict(model, x,activFunLayer1,activFunLayer2),numNodes)

# %%
def nn(X,y,numNodes,activFunLayer1,activFunLayer2,num_passes,epsilon,reg_lambda,print_loss):

    # loss function for a 3-layer MLP
    def loss(model, activFunLayer1,activFunLayer2):
        W1, b1, W2, b2,W3,b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
        print(W1.shape,W2.shape,W3.shape)
        # Forward propagation to calculate our predictions
        z1 = np.dot(X,W1) + b1
        a1 = activFunLayer1(z1)


        z2 = np.dot(a1,W2) + b2
        a2 = activFunLayer2(z2)

        z3 = np.dot(a2,W3) + b3
        
        exp_scores = np.exp(z3)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        # Calculating the loss
        
        corect_logprobs = -np.log(probs[range(num_examples), y])
        
        data_loss = np.sum(corect_logprobs)
        # Add regulatization term to loss (optional)
        data_loss += reg_lambda * (np.sum(np.square(W1)) + np.sum(np.square(W2)) + np.sum(np.square(W3)))
        return 1./num_examples * data_loss
    
    # forward propagation
    def predict(model, x,activFunLayer1,activFunLayer2):
        W1, b1, W2, b2,W3,b3 = model['W1'], model['b1'], model['W2'], model['b2'], model['W3'], model['b3']
        z1 = np.dot(x,W1) + b1
        a1 = activFunLayer1(z1)

        z2 = np.dot(a1,W2) + b2
        a2 = activFunLayer2(z2)

        z3 = np.dot(a2,W3) + b3
        exp_scores = np.exp(z3)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        return np.argmax(probs, axis=1)
    
    
    def build_model(nn_hdim, activFunLayer1,activFunLayer2, num_passes, print_loss):
    
        # Initialize the parameters to random values. 
        np.random.seed(0)
        W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
        b1 = np.zeros((1, nn_hdim))

        W2 = np.random.randn(nn_hdim, nn_hdim) / np.sqrt(nn_hdim)
        b2 = np.zeros((1, nn_hdim)) 

        W3 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
        b3 = np.zeros((1, nn_output_dim))

        # This is what we return at the end
        model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3':W3, 'b3':b3}

        # Gradient descent. For each batch...
        for i in range(0, num_passes):

            # Forward propagation
            #predict(model, X,activFunLayer1,activFunLayer2)

            # computing the derivative by AD        
            gradient_loss = grad(loss)

            # flattening nested containers containing numpy arrays
            # Returns 1D numpy array and an unflatten function.
            model_flat, unflatten_m = flatten(model)
            grad_flat, unflatten_g = flatten(gradient_loss(model,activFunLayer1,activFunLayer2))

            # gradient descend
            model_flat -= grad_flat * epsilon
            model = unflatten_m(model_flat)

            # Optionally print the loss.
            # This is expensive because it uses the whole dataset, so we don't want to do it too often.
            if print_loss and i % 1000 == 0:
                print("Loss after iteration %i: %f" %(i, loss(model,activFunLayer1,activFunLayer2)))

        return model
    
    def plot_decision_boundary(pred_func,numNodes):
        # Set min and max values and give it some padding
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)
        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, alpha=0.45)
        plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.45)
        # Plot the decision boundary
        plt.title("Decision Boundary for hidden layer size "+str(numNodes))
        
    
    
    num_examples = len(X) # training set size
    nn_input_dim = 2 # input layer dimensionality
    nn_output_dim = 2 # output layer dimensionality
    
    model = build_model(numNodes, activFunLayer1,activFunLayer2,num_passes,print_loss)
    plot_decision_boundary(lambda x: predict(model, x,activFunLayer1,activFunLayer2),numNodes)

# %%
def relu(x):
    return np.maximum(0,x)

def tanh(x):
    return np.tanh(x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def twospirals(n_points, noise=.5):
    """
     Returns the two spirals dataset.
    """
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(n_points),np.ones(n_points))))

# %%
XMoon,yMoon = sklearn.datasets.make_moons(1000, noise=0.20)
XSpiral,ySpiral = twospirals(1000)
ySpiral = ySpiral.astype(np.int64)

# %%
nn(XMoon,yMoon,numNodes=4,activFunLayer1=tanh,activFunLayer2=tanh,num_passes=9000,epsilon=0.01,reg_lambda=0.01,print_loss=True)
# Out:
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# Loss after iteration 0: 0.565379
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# Loss after iteration 1000: 0.347356
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# (2, 4) (4, 4) (4, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-157-ca8d6e5d611a> in <module>
# ----> 1 nn(XMoon,yMoon,numNodes=4,activFunLayer1=tanh,activFunLayer2=tanh,num_passes=9000,epsilon=0.01,reg_lambda=0.01,print_loss=True)
#
# <ipython-input-156-c3391459d23a> in nn(X, y, numNodes, activFunLayer1, activFunLayer2, num_passes, epsilon, reg_lambda, print_loss)
#     104     nn_output_dim = 2 # output layer dimensionality
#     105
# --> 106     model = build_model(numNodes, activFunLayer1,activFunLayer2,num_passes,print_loss)
#     107     plot_decision_boundary(lambda x: predict(model, x,activFunLayer1,activFunLayer2),numNodes)
#     108
#
# <ipython-input-156-c3391459d23a> in build_model(nn_hdim, activFunLayer1, activFunLayer2, num_passes, print_loss)
#      69             # Returns 1D numpy array and an unflatten function.
#      70             model_flat, unflatten_m = flatten(model)
# ---> 71             grad_flat, unflatten_g = flatten(gradient_loss(model,activFunLayer1,activFunLayer2))
#      72
#      73             # gradient descend
#
# ~\anaconda3\lib\site-packages\autograd\wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~\anaconda3\lib\site-packages\autograd\differential_operators.py in grad(fun, x)
#      27         raise TypeError("Grad only applies to real scalar-output functions. "
#      28                         "Try jacobian, elementwise_grad or holomorphic_grad.")
# ---> 29     return vjp(vspace(ans).ones())
#      30
#      31 @unary_to_nary
#
# ~\anaconda3\lib\site-packages\autograd\core.py in vjp(g)
#      12         def vjp(g): return vspace(x).zeros()
#      13     else:
# ---> 14         def vjp(g): return backward_pass(g, end_node)
#      15     return vjp, end_value
#      16
#
# ~\anaconda3\lib\site-packages\autograd\core.py in backward_pass(g, end_node)
#      19     for node in toposort(end_node):
#      20         outgrad = outgrads.pop(node)
# ---> 21         ingrads = node.vjp(outgrad[0])
#      22         for parent, ingrad in zip(node.parents, ingrads):
#      23             outgrads[parent] = add_outgrads(outgrads.get(parent), ingrad)
#
# ~\anaconda3\lib\site-packages\autograd\core.py in <lambda>(g)
#      65                     "VJP of {} wrt argnum 0 not defined".format(fun.__name__))
#      66             vjp = vjpfun(ans, *args, **kwargs)
# ---> 67             return lambda g: (vjp(g),)
#      68         elif L == 2:
#      69             argnum_0, argnum_1 = argnums
#
# ~\anaconda3\lib\site-packages\autograd\numpy\numpy_vjps.py in <lambda>(g)
#     297 def grad_np_sum(ans, x, axis=None, keepdims=False, dtype=None):
#     298     shape, dtype = anp.shape(x), anp.result_type(x)
# --> 299     return lambda g: repeat_to_match_shape(g, shape, dtype, axis, keepdims)[0]
#     300 defvjp(anp.sum, grad_np_sum)
#     301
#
# ~\anaconda3\lib\site-packages\autograd\numpy\numpy_vjps.py in repeat_to_match_shape(g, shape, dtype, axis, keepdims)
#     283     # Can't use broadcast_to because of numpy bug: https://github.com/numpy/numpy/issues/9165
#     284     # return anp.broadcast_to(anp.reshape(g, new_shape), shape), num_reps
# --> 285     return anp.reshape(g, new_shape) + onp.zeros(shape, dtype=dtype), num_reps
#     286
#     287 def grad_broadcast_to(ans, x, new_shape):
#
# KeyboardInterrupt:

# %%
nn(X,y,numNodes=4,activFunLayer1=tanh,activFunLayer2=sigmoid,num_passes=50000,epsilon=0.01,reg_lambda=0.01,print_loss=False)

# %%
nn(XMoon,yMoon,numNodes=4,activFunLayer1=tanh,activFunLayer2=sigmoid,num_passes=5000,epsilon=0.01,reg_lambda=0.01,print_loss=False)

# %%
nn(XSpiral,ySpiral,numNodes=4,activFunLayer1=tanh,activFunLayer2=tanh,num_passes=50000,epsilon=0.01,reg_lambda=0.01,print_loss=True)
# Out:
# Loss after iteration 0: 0.795135
# Loss after iteration 1000: 0.688201
# Loss after iteration 2000: 0.683027
# Loss after iteration 3000: 0.682538
# Loss after iteration 4000: 0.682369
# Loss after iteration 5000: 0.682244
# Loss after iteration 6000: 0.682138
# Loss after iteration 7000: 0.682045
# Loss after iteration 8000: 0.681961
# Loss after iteration 9000: 0.681883
# Loss after iteration 10000: 0.681811
# Loss after iteration 11000: 0.681743
# Loss after iteration 12000: 0.681677
# Loss after iteration 13000: 0.681614
# Loss after iteration 14000: 0.681553
# Loss after iteration 15000: 0.681492
# Loss after iteration 16000: 0.681433
# Loss after iteration 17000: 0.681373
# Loss after iteration 18000: 0.681313
# Loss after iteration 19000: 0.681252
# Loss after iteration 20000: 0.681190
# Loss after iteration 21000: 0.681126
# Loss after iteration 22000: 0.681060
# Loss after iteration 23000: 0.680990
# Loss after iteration 24000: 0.680915
# Loss after iteration 25000: 0.680835
# Loss after iteration 26000: 0.680747
# Loss after iteration 27000: 0.680651
# Loss after iteration 28000: 0.680544
# Loss after iteration 29000: 0.680425
# Loss after iteration 30000: 0.680287
# Loss after iteration 31000: 0.680111
# Loss after iteration 32000: 0.679777
# Loss after iteration 33000: 0.678719
# Loss after iteration 34000: 0.677289
# Loss after iteration 35000: 0.676520
# Loss after iteration 36000: 0.676049
# Loss after iteration 37000: 0.675697
# Loss after iteration 38000: 0.675378
# Loss after iteration 39000: 0.675045
# Loss after iteration 40000: 0.674670
# Loss after iteration 41000: 0.674233
# Loss after iteration 42000: 0.673723
# Loss after iteration 43000: 0.673135
# Loss after iteration 44000: 0.672458
# Loss after iteration 45000: 0.671679
# Loss after iteration 46000: 0.670789
# Loss after iteration 47000: 0.669807
# Loss after iteration 48000: 0.668807
# Loss after iteration 49000: 0.667870

# %%
# your code here
